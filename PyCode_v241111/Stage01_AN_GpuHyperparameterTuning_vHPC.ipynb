# %% [markdown]
# # Hyperparameter Search

# %% [markdown]
# In V2 more hyperparameters are considered and larger range

# %%
# %pwd
# Out:
# '/home/pj24001881/ku40001335/Greenness_NighttimeLight_WB/PyCode_v241111'

# %%
# %cd ..
# Out:
# /home/pj24001881/ku40001335/Greenness_NighttimeLight_WB

# %% [markdown]
# ## Import Package

# %%
import cudf
from glob import glob
from joblib import dump, load
import numpy as np
import pandas as pd
import random
from cuml.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score, make_scorer, accuracy_score
from sklearn.model_selection import train_test_split, KFold, RandomizedSearchCV

# %%
import warnings

warnings.filterwarnings(
    "ignore", 
    message="To use pickling first train using float32 data to fit the estimator"
)

# %% [markdown]
# ### Function

# %%
### X and y
def getXandY(Output_Vari):
    y_list = glob("01_Data/*_y_" + Output_Vari + "*.csv")
    y = pd.read_csv(y_list[0], index_col=0)
    y = y.iloc[:,0].to_numpy()
    X_list = glob("01_Data/*_X_" + Output_Vari + "*.csv")
    X = pd.read_csv(X_list[0], index_col=0)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, 
                                                        random_state=1)
    return X_train, X_test, y_train, y_test

# %% [markdown]
# ## Experiment for Happiness

# %% [markdown]
# ### Load Data

# %%
Output_Vari = "Happinessoverall"

# %%
X_train, X_test, y_train, y_test = getXandY(Output_Vari)

# %%
X_train.head()
# Out:
#         year        lat         lon  female  age  high_stress  low_stress  \
# 329671  2016  37.183964  138.256897       1   51            4           5
# 24633   2015  37.239090  140.353348       1   26            5           5
# 279845  2016  35.528252  140.185822       0   67            2           1
# 269295  2016  33.566044  130.342041       1   35            1           3
# 232515  2015  33.619823  130.515259       1   32            4           4
#
#         easy_to_relax  good_for_living  live_environment_satefy  ...  \
# 329671              3                4                        3  ...
# 24633               3                3                        4  ...
# 279845              4                4                        3  ...
# 269295              4                4                        3  ...
# 232515              2                4                        3  ...
#
#         housewife  retired  unemployed  college_no_diploma  bachelor  master  \
# 329671          0        0           0                   0         0       0
# 24633           0        0           0                   1         0       0
# 279845          0        0           0                   0         1       0
# 269295          1        0           0                   1         0       0
# 232515          1        0           0                   0         1       0
#
#         phd  income_indiv       NDVI        NTL
# 329671    0           3.5  29.553186   4.315041
# 24633     0           1.0  40.441441   2.005019
# 279845    0           1.0  53.940829   7.728996
# 269295    0           1.0  30.014896  17.481237
# 232515    0           2.5  55.156878   5.779940
#
# [5 rows x 29 columns]

# %%
X_train.describe()
# Out:
#                 year            lat            lon         female  \
# count  344855.000000  344855.000000  344855.000000  344855.000000
# mean     2015.656540      35.708914     137.514520       0.352612
# std         0.771443       2.131133       3.052344       0.477784
# min      2015.000000      24.301767     123.762947       0.000000
# 25%      2015.000000      34.747284     135.545242       0.000000
# 50%      2015.000000      35.477516     138.984985       0.000000
# 75%      2016.000000      35.809013     139.715393       1.000000
# max      2017.000000      45.511021     145.742340       1.000000
#
#                  age    high_stress     low_stress  easy_to_relax  \
# count  344855.000000  344855.000000  344855.000000  344855.000000
# mean       48.967114       3.172557       3.606846       3.293581
# std        11.731917       1.166244       1.060261       1.020122
# min        17.000000       1.000000       1.000000       1.000000
# 25%        41.000000       2.000000       3.000000       3.000000
# 50%        49.000000       3.000000       4.000000       4.000000
# 75%        57.000000       4.000000       4.000000       4.000000
# max       101.000000       5.000000       5.000000       5.000000
#
#        good_for_living  live_environment_satefy  ...      housewife  \
# count    344855.000000            344855.000000  ...  344855.000000
# mean          3.826623                 2.953085  ...       0.086381
# std           0.897251                 0.761716  ...       0.280927
# min           1.000000                 0.000000  ...       0.000000
# 25%           3.000000                 3.000000  ...       0.000000
# 50%           4.000000                 3.000000  ...       0.000000
# 75%           4.000000                 3.000000  ...       0.000000
# max           5.000000                 4.000000  ...       1.000000
#
#              retired     unemployed  college_no_diploma       bachelor  \
# count  344855.000000  344855.000000       344855.000000  344855.000000
# mean        0.064410       0.046147            0.209624       0.437245
# std         0.245482       0.209804            0.407041       0.496047
# min         0.000000       0.000000            0.000000       0.000000
# 25%         0.000000       0.000000            0.000000       0.000000
# 50%         0.000000       0.000000            0.000000       0.000000
# 75%         0.000000       0.000000            0.000000       1.000000
# max         1.000000       1.000000            1.000000       1.000000
#
#               master            phd   income_indiv           NDVI  \
# count  344855.000000  344855.000000  344855.000000  344855.000000
# mean        0.047295       0.013539       4.686452      36.247119
# std         0.212270       0.115567       3.903289      13.664925
# min         0.000000       0.000000       1.000000       4.860561
# 25%         0.000000       0.000000       1.000000      26.247235
# 50%         0.000000       0.000000       3.500000      34.654246
# 75%         0.000000       0.000000       6.500000      44.238307
# max         1.000000       1.000000      30.000000      87.709065
#
#                  NTL
# count  344855.000000
# mean       18.599653
# std        15.865111
# min         0.013894
# 25%         6.048134
# 50%        14.545732
# 75%        26.747059
# max        88.380999
#
# [8 rows x 29 columns]

# %%
X_train.columns
# Out:
# Index(['year', 'lat', 'lon', 'female', 'age', 'high_stress', 'low_stress',
#        'easy_to_relax', 'good_for_living', 'live_environment_satefy',
#        'community_attachment', 'income', 'self_reported_health', 'student',
#        'worker', 'company_owner', 'government_officer', 'self_employed',
#        'professional', 'housewife', 'retired', 'unemployed',
#        'college_no_diploma', 'bachelor', 'master', 'phd', 'income_indiv',
#        'NDVI', 'NTL'],
#       dtype='object')

# %%
X_train.shape
# Out:
# (344855, 29)

# %%
X_test.shape
# Out:
# (38318, 29)

# %%
X = pd.concat([X_train, X_test])

# %%
X.shape
# Out:
# (383173, 29)

# %%
y = np.concatenate([y_train, y_test])

# %%
y.shape
# Out:
# (383173,)

# %% [markdown]
# ### Run Test Model

# %%
rf_reg =RandomForestRegressor(n_bins=256)

# %%
param_grid = {
    "n_estimators": list(range(1_000, 5_100, 100)),
    "max_depth": [2, 4, 8, 16],
    "max_features": [0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
    "min_samples_split": [2, 4, 8, 16, 32],
    "max_samples": [0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1.0]
}

# %%
class RandomRunNFoldsKFold(KFold):
    def __init__(self, n_splits=10, random_state=None, run_splits=3, **kwargs):
        super().__init__(n_splits=n_splits, shuffle=True, random_state=random_state, **kwargs)
        self.random_state = random_state
        self.actual_splits = run_splits  # Number of actual splits to use

    def split(self, X, y=None, groups=None):
        folds = list(super().split(X, y, groups))
        if self.random_state is not None:
            random.seed(self.random_state)
        selected_folds = random.sample(folds, self.actual_splits)
        for train_index, test_index in selected_folds:
            yield train_index, test_index

    def get_n_splits(self, X=None, y=None, groups=None):
        return self.actual_splits

# %%
rkfcv = RandomRunNFoldsKFold(n_splits=10, run_splits=3, random_state=42)

# %%
random_search = RandomizedSearchCV(
    estimator=rf_reg,
    param_distributions=param_grid,
    n_iter=500,  # Number of parameter settings to sample
    scoring="r2",
    cv=rkfcv,  # 3-fold cross-validation
    random_state=42,
    verbose=2,
    return_train_score = False
)

# %%
# Fit the model
random_search.fit(X, y)
# Out:
# Fitting 3 folds for each of 500 candidates, totalling 1500 fits
# [CV] END max_depth=2, max_features=0.6, max_samples=0.8, min_samples_split=2, n_estimators=1800; total time=  18.4s
# [CV] END max_depth=2, max_features=0.6, max_samples=0.8, min_samples_split=2, n_estimators=1800; total time=  12.7s
# [CV] END max_depth=2, max_features=0.6, max_samples=0.8, min_samples_split=2, n_estimators=1800; total time=  14.3s
# [CV] END max_depth=2, max_features=0.5, max_samples=0.5, min_samples_split=32, n_estimators=1400; total time=   7.4s
# [CV] END max_depth=2, max_features=0.5, max_samples=0.5, min_samples_split=32, n_estimators=1400; total time=   7.5s
# [CV] END max_depth=2, max_features=0.5, max_samples=0.5, min_samples_split=32, n_estimators=1400; total time=   8.4s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.6, min_samples_split=32, n_estimators=2100; total time=  12.4s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.6, min_samples_split=32, n_estimators=2100; total time=  12.6s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.6, min_samples_split=32, n_estimators=2100; total time=  12.4s
# [CV] END max_depth=2, max_features=1.0, max_samples=0.5, min_samples_split=32, n_estimators=3900; total time=  20.4s
# [CV] END max_depth=2, max_features=1.0, max_samples=0.5, min_samples_split=32, n_estimators=3900; total time=  20.8s
# [CV] END max_depth=2, max_features=1.0, max_samples=0.5, min_samples_split=32, n_estimators=3900; total time=  20.4s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.8, min_samples_split=2, n_estimators=3200; total time=  23.5s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.8, min_samples_split=2, n_estimators=3200; total time=  23.3s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.8, min_samples_split=2, n_estimators=3200; total time=  23.5s
# [CV] END max_depth=2, max_features=0.7, max_samples=0.8, min_samples_split=8, n_estimators=3400; total time=  26.8s
# [CV] END max_depth=2, max_features=0.7, max_samples=0.8, min_samples_split=8, n_estimators=3400; total time=  26.9s
# [CV] END max_depth=2, max_features=0.7, max_samples=0.8, min_samples_split=8, n_estimators=3400; total time=  26.3s
# [CV] END max_depth=2, max_features=0.6, max_samples=0.8, min_samples_split=32, n_estimators=3200; total time=  24.9s
# [CV] END max_depth=2, max_features=0.6, max_samples=0.8, min_samples_split=32, n_estimators=3200; total time=  25.2s
# [CV] END max_depth=2, max_features=0.6, max_samples=0.8, min_samples_split=32, n_estimators=3200; total time=  24.9s
# [CV] END max_depth=2, max_features=0.8, max_samples=0.5, min_samples_split=2, n_estimators=1900; total time=  10.0s
# [CV] END max_depth=2, max_features=0.8, max_samples=0.5, min_samples_split=2, n_estimators=1900; total time=  10.0s
# [CV] END max_depth=2, max_features=0.8, max_samples=0.5, min_samples_split=2, n_estimators=1900; total time=  10.1s
# [CV] END max_depth=8, max_features=0.8, max_samples=0.5, min_samples_split=2, n_estimators=1800; total time=  10.7s
# [CV] END max_depth=8, max_features=0.8, max_samples=0.5, min_samples_split=2, n_estimators=1800; total time=  10.8s
# [CV] END max_depth=8, max_features=0.8, max_samples=0.5, min_samples_split=2, n_estimators=1800; total time=  10.6s
# [CV] END max_depth=16, max_features=0.4, max_samples=0.5, min_samples_split=16, n_estimators=3800; total time=  26.3s
# [CV] END max_depth=16, max_features=0.4, max_samples=0.5, min_samples_split=16, n_estimators=3800; total time=  26.3s
# [CV] END max_depth=16, max_features=0.4, max_samples=0.5, min_samples_split=16, n_estimators=3800; total time=  26.2s
# [CV] END max_depth=4, max_features=0.9, max_samples=0.6, min_samples_split=4, n_estimators=1800; total time=  10.6s
# [CV] END max_depth=4, max_features=0.9, max_samples=0.6, min_samples_split=4, n_estimators=1800; total time=  10.0s
# [CV] END max_depth=4, max_features=0.9, max_samples=0.6, min_samples_split=4, n_estimators=1800; total time=  10.0s
# [CV] END max_depth=2, max_features=0.8, max_samples=0.9, min_samples_split=4, n_estimators=3600; total time=  30.9s
# [CV] END max_depth=2, max_features=0.8, max_samples=0.9, min_samples_split=4, n_estimators=3600; total time=  31.2s
# [CV] END max_depth=2, max_features=0.8, max_samples=0.9, min_samples_split=4, n_estimators=3600; total time=  31.1s
# [CV] END max_depth=2, max_features=1.0, max_samples=0.8, min_samples_split=16, n_estimators=1300; total time=  10.2s
# [CV] END max_depth=2, max_features=1.0, max_samples=0.8, min_samples_split=16, n_estimators=1300; total time=  10.5s
# [CV] END max_depth=2, max_features=1.0, max_samples=0.8, min_samples_split=16, n_estimators=1300; total time=  10.4s
# [CV] END max_depth=4, max_features=0.9, max_samples=0.7, min_samples_split=4, n_estimators=1100; total time=   7.0s
# [CV] END max_depth=4, max_features=0.9, max_samples=0.7, min_samples_split=4, n_estimators=1100; total time=   7.1s
# [CV] END max_depth=4, max_features=0.9, max_samples=0.7, min_samples_split=4, n_estimators=1100; total time=   7.1s
# [CV] END max_depth=16, max_features=0.9, max_samples=0.4, min_samples_split=16, n_estimators=1100; total time=   8.4s
# [CV] END max_depth=16, max_features=0.9, max_samples=0.4, min_samples_split=16, n_estimators=1100; total time=   8.4s
# [CV] END max_depth=16, max_features=0.9, max_samples=0.4, min_samples_split=16, n_estimators=1100; total time=   8.5s
# [CV] END max_depth=4, max_features=0.9, max_samples=0.4, min_samples_split=4, n_estimators=3000; total time=  11.6s
# [CV] END max_depth=4, max_features=0.9, max_samples=0.4, min_samples_split=4, n_estimators=3000; total time=  11.7s
# [CV] END max_depth=4, max_features=0.9, max_samples=0.4, min_samples_split=4, n_estimators=3000; total time=  11.6s
# [CV] END max_depth=16, max_features=0.6, max_samples=0.7, min_samples_split=16, n_estimators=4800; total time=  49.3s
# [CV] END max_depth=16, max_features=0.6, max_samples=0.7, min_samples_split=16, n_estimators=4800; total time=  50.0s
# [CV] END max_depth=16, max_features=0.6, max_samples=0.7, min_samples_split=16, n_estimators=4800; total time=  50.2s
# [CV] END max_depth=4, max_features=0.5, max_samples=0.8, min_samples_split=2, n_estimators=3700; total time=  24.9s
# [CV] END max_depth=4, max_features=0.5, max_samples=0.8, min_samples_split=2, n_estimators=3700; total time=  24.5s
# [CV] END max_depth=4, max_features=0.5, max_samples=0.8, min_samples_split=2, n_estimators=3700; total time=  24.4s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.7, min_samples_split=2, n_estimators=1400; total time=  12.5s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.7, min_samples_split=2, n_estimators=1400; total time=  12.5s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.7, min_samples_split=2, n_estimators=1400; total time=  12.6s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.4, min_samples_split=32, n_estimators=1400; total time=   7.5s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.4, min_samples_split=32, n_estimators=1400; total time=   7.5s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.4, min_samples_split=32, n_estimators=1400; total time=   7.5s
# [CV] END max_depth=16, max_features=0.5, max_samples=1.0, min_samples_split=16, n_estimators=2200; total time=  28.5s
# [CV] END max_depth=16, max_features=0.5, max_samples=1.0, min_samples_split=16, n_estimators=2200; total time=  28.6s
# [CV] END max_depth=16, max_features=0.5, max_samples=1.0, min_samples_split=16, n_estimators=2200; total time=  29.1s
# [CV] END max_depth=2, max_features=1.0, max_samples=0.6, min_samples_split=8, n_estimators=3600; total time=  22.0s
# [CV] END max_depth=2, max_features=1.0, max_samples=0.6, min_samples_split=8, n_estimators=3600; total time=  22.7s
# [CV] END max_depth=2, max_features=1.0, max_samples=0.6, min_samples_split=8, n_estimators=3600; total time=  22.5s
# [CV] END max_depth=8, max_features=1.0, max_samples=1.0, min_samples_split=32, n_estimators=1000; total time=  12.2s
# [CV] END max_depth=8, max_features=1.0, max_samples=1.0, min_samples_split=32, n_estimators=1000; total time=  12.4s
# [CV] END max_depth=8, max_features=1.0, max_samples=1.0, min_samples_split=32, n_estimators=1000; total time=  12.3s
# [CV] END max_depth=4, max_features=0.9, max_samples=0.9, min_samples_split=8, n_estimators=4100; total time=  32.2s
# [CV] END max_depth=4, max_features=0.9, max_samples=0.9, min_samples_split=8, n_estimators=4100; total time=  31.9s
# [CV] END max_depth=4, max_features=0.9, max_samples=0.9, min_samples_split=8, n_estimators=4100; total time=  32.4s
# [CV] END max_depth=16, max_features=1.0, max_samples=1.0, min_samples_split=8, n_estimators=5000; total time= 1.6min
# [CV] END max_depth=16, max_features=1.0, max_samples=1.0, min_samples_split=8, n_estimators=5000; total time= 1.6min
# [CV] END max_depth=16, max_features=1.0, max_samples=1.0, min_samples_split=8, n_estimators=5000; total time= 1.6min
# [CV] END max_depth=8, max_features=0.9, max_samples=0.9, min_samples_split=8, n_estimators=4000; total time=  42.8s
# [CV] END max_depth=8, max_features=0.9, max_samples=0.9, min_samples_split=8, n_estimators=4000; total time=  42.4s
# [CV] END max_depth=8, max_features=0.9, max_samples=0.9, min_samples_split=8, n_estimators=4000; total time=  42.1s
# [CV] END max_depth=16, max_features=0.5, max_samples=0.9, min_samples_split=16, n_estimators=4800; total time=  57.0s
# [CV] END max_depth=16, max_features=0.5, max_samples=0.9, min_samples_split=16, n_estimators=4800; total time=  58.5s
# [CV] END max_depth=16, max_features=0.5, max_samples=0.9, min_samples_split=16, n_estimators=4800; total time=  57.8s
# [CV] END max_depth=2, max_features=0.6, max_samples=0.4, min_samples_split=16, n_estimators=3500; total time=  14.8s
# [CV] END max_depth=2, max_features=0.6, max_samples=0.4, min_samples_split=16, n_estimators=3500; total time=  14.9s
# [CV] END max_depth=2, max_features=0.6, max_samples=0.4, min_samples_split=16, n_estimators=3500; total time=  14.8s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.4, min_samples_split=8, n_estimators=1700; total time=   7.2s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.4, min_samples_split=8, n_estimators=1700; total time=   7.2s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.4, min_samples_split=8, n_estimators=1700; total time=   7.2s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.4, min_samples_split=16, n_estimators=2700; total time=  10.7s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.4, min_samples_split=16, n_estimators=2700; total time=  10.8s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.4, min_samples_split=16, n_estimators=2700; total time=  10.9s
# [CV] END max_depth=4, max_features=0.5, max_samples=0.6, min_samples_split=16, n_estimators=2700; total time=  14.2s
# [CV] END max_depth=4, max_features=0.5, max_samples=0.6, min_samples_split=16, n_estimators=2700; total time=  14.2s
# [CV] END max_depth=4, max_features=0.5, max_samples=0.6, min_samples_split=16, n_estimators=2700; total time=  14.2s
# [CV] END max_depth=4, max_features=0.6, max_samples=0.9, min_samples_split=4, n_estimators=4900; total time=  37.6s
# [CV] END max_depth=4, max_features=0.6, max_samples=0.9, min_samples_split=4, n_estimators=4900; total time=  36.3s
# [CV] END max_depth=4, max_features=0.6, max_samples=0.9, min_samples_split=4, n_estimators=4900; total time=  36.4s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.8, min_samples_split=16, n_estimators=1000; total time=  10.2s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.8, min_samples_split=16, n_estimators=1000; total time=  10.1s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.8, min_samples_split=16, n_estimators=1000; total time=  10.0s
# [CV] END max_depth=16, max_features=0.4, max_samples=0.9, min_samples_split=8, n_estimators=1800; total time=  20.5s
# [CV] END max_depth=16, max_features=0.4, max_samples=0.9, min_samples_split=8, n_estimators=1800; total time=  20.7s
# [CV] END max_depth=16, max_features=0.4, max_samples=0.9, min_samples_split=8, n_estimators=1800; total time=  20.6s
# [CV] END max_depth=16, max_features=0.5, max_samples=0.6, min_samples_split=2, n_estimators=2400; total time=  23.6s
# [CV] END max_depth=16, max_features=0.5, max_samples=0.6, min_samples_split=2, n_estimators=2400; total time=  23.1s
# [CV] END max_depth=16, max_features=0.5, max_samples=0.6, min_samples_split=2, n_estimators=2400; total time=  22.8s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.9, min_samples_split=2, n_estimators=1600; total time=  13.6s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.9, min_samples_split=2, n_estimators=1600; total time=  13.2s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.9, min_samples_split=2, n_estimators=1600; total time=  13.1s
# [CV] END max_depth=4, max_features=0.6, max_samples=0.6, min_samples_split=16, n_estimators=3300; total time=  17.5s
# [CV] END max_depth=4, max_features=0.6, max_samples=0.6, min_samples_split=16, n_estimators=3300; total time=  17.3s
# [CV] END max_depth=4, max_features=0.6, max_samples=0.6, min_samples_split=16, n_estimators=3300; total time=  17.4s
# [CV] END max_depth=8, max_features=0.9, max_samples=0.7, min_samples_split=4, n_estimators=3600; total time=  30.4s
# [CV] END max_depth=8, max_features=0.9, max_samples=0.7, min_samples_split=4, n_estimators=3600; total time=  30.1s
# [CV] END max_depth=8, max_features=0.9, max_samples=0.7, min_samples_split=4, n_estimators=3600; total time=  30.3s
# [CV] END max_depth=16, max_features=0.5, max_samples=0.9, min_samples_split=8, n_estimators=1200; total time=  14.7s
# [CV] END max_depth=16, max_features=0.5, max_samples=0.9, min_samples_split=8, n_estimators=1200; total time=  14.6s
# [CV] END max_depth=16, max_features=0.5, max_samples=0.9, min_samples_split=8, n_estimators=1200; total time=  14.7s
# [CV] END max_depth=4, max_features=0.8, max_samples=0.8, min_samples_split=16, n_estimators=4600; total time=  31.5s
# [CV] END max_depth=4, max_features=0.8, max_samples=0.8, min_samples_split=16, n_estimators=4600; total time=  31.5s
# [CV] END max_depth=4, max_features=0.8, max_samples=0.8, min_samples_split=16, n_estimators=4600; total time=  31.7s
# [CV] END max_depth=2, max_features=0.9, max_samples=0.8, min_samples_split=16, n_estimators=4500; total time=  35.2s
# [CV] END max_depth=2, max_features=0.9, max_samples=0.8, min_samples_split=16, n_estimators=4500; total time=  35.7s
# [CV] END max_depth=2, max_features=0.9, max_samples=0.8, min_samples_split=16, n_estimators=4500; total time=  35.4s
# [CV] END max_depth=16, max_features=1.0, max_samples=0.4, min_samples_split=16, n_estimators=4200; total time=  33.7s
# [CV] END max_depth=16, max_features=1.0, max_samples=0.4, min_samples_split=16, n_estimators=4200; total time=  35.9s
# [CV] END max_depth=16, max_features=1.0, max_samples=0.4, min_samples_split=16, n_estimators=4200; total time=  34.1s
# [CV] END max_depth=2, max_features=0.9, max_samples=0.5, min_samples_split=32, n_estimators=2900; total time=  15.9s
# [CV] END max_depth=2, max_features=0.9, max_samples=0.5, min_samples_split=32, n_estimators=2900; total time=  15.3s
# [CV] END max_depth=2, max_features=0.9, max_samples=0.5, min_samples_split=32, n_estimators=2900; total time=  15.0s
# [CV] END max_depth=16, max_features=0.7, max_samples=0.5, min_samples_split=8, n_estimators=1400; total time=  11.9s
# [CV] END max_depth=16, max_features=0.7, max_samples=0.5, min_samples_split=8, n_estimators=1400; total time=  11.7s
# [CV] END max_depth=16, max_features=0.7, max_samples=0.5, min_samples_split=8, n_estimators=1400; total time=  11.9s
# [CV] END max_depth=2, max_features=0.5, max_samples=0.4, min_samples_split=2, n_estimators=3900; total time=  16.6s
# [CV] END max_depth=2, max_features=0.5, max_samples=0.4, min_samples_split=2, n_estimators=3900; total time=  16.5s
# [CV] END max_depth=2, max_features=0.5, max_samples=0.4, min_samples_split=2, n_estimators=3900; total time=  16.6s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.8, min_samples_split=16, n_estimators=1000; total time=   7.4s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.8, min_samples_split=16, n_estimators=1000; total time=   7.4s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.8, min_samples_split=16, n_estimators=1000; total time=   7.5s
# [CV] END max_depth=16, max_features=1.0, max_samples=0.9, min_samples_split=16, n_estimators=3900; total time= 1.1min
# [CV] END max_depth=16, max_features=1.0, max_samples=0.9, min_samples_split=16, n_estimators=3900; total time= 1.1min
# [CV] END max_depth=16, max_features=1.0, max_samples=0.9, min_samples_split=16, n_estimators=3900; total time= 1.1min
# [CV] END max_depth=16, max_features=0.9, max_samples=0.8, min_samples_split=4, n_estimators=1600; total time=  23.2s
# [CV] END max_depth=16, max_features=0.9, max_samples=0.8, min_samples_split=4, n_estimators=1600; total time=  23.3s
# [CV] END max_depth=16, max_features=0.9, max_samples=0.8, min_samples_split=4, n_estimators=1600; total time=  23.3s
# [CV] END max_depth=8, max_features=0.9, max_samples=1.0, min_samples_split=4, n_estimators=5000; total time=  57.4s
# [CV] END max_depth=8, max_features=0.9, max_samples=1.0, min_samples_split=4, n_estimators=5000; total time=  57.3s
# [CV] END max_depth=8, max_features=0.9, max_samples=1.0, min_samples_split=4, n_estimators=5000; total time=  57.5s
# [CV] END max_depth=4, max_features=0.6, max_samples=1.0, min_samples_split=8, n_estimators=1200; total time=   9.9s
# [CV] END max_depth=4, max_features=0.6, max_samples=1.0, min_samples_split=8, n_estimators=1200; total time=   9.9s
# [CV] END max_depth=4, max_features=0.6, max_samples=1.0, min_samples_split=8, n_estimators=1200; total time=   9.9s
# [CV] END max_depth=16, max_features=0.4, max_samples=0.5, min_samples_split=8, n_estimators=3900; total time=  27.7s
# [CV] END max_depth=16, max_features=0.4, max_samples=0.5, min_samples_split=8, n_estimators=3900; total time=  27.7s
# [CV] END max_depth=16, max_features=0.4, max_samples=0.5, min_samples_split=8, n_estimators=3900; total time=  27.7s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.4, min_samples_split=16, n_estimators=1300; total time=   5.5s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.4, min_samples_split=16, n_estimators=1300; total time=   5.7s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.4, min_samples_split=16, n_estimators=1300; total time=   5.6s
# [CV] END max_depth=4, max_features=0.5, max_samples=0.7, min_samples_split=4, n_estimators=1400; total time=   8.8s
# [CV] END max_depth=4, max_features=0.5, max_samples=0.7, min_samples_split=4, n_estimators=1400; total time=   8.4s
# [CV] END max_depth=4, max_features=0.5, max_samples=0.7, min_samples_split=4, n_estimators=1400; total time=   8.4s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.4, min_samples_split=32, n_estimators=3300; total time=  13.1s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.4, min_samples_split=32, n_estimators=3300; total time=  13.2s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.4, min_samples_split=32, n_estimators=3300; total time=  13.3s
# [CV] END max_depth=8, max_features=0.7, max_samples=0.7, min_samples_split=2, n_estimators=1500; total time=  11.7s
# [CV] END max_depth=8, max_features=0.7, max_samples=0.7, min_samples_split=2, n_estimators=1500; total time=  11.7s
# [CV] END max_depth=8, max_features=0.7, max_samples=0.7, min_samples_split=2, n_estimators=1500; total time=  11.7s
# [CV] END max_depth=8, max_features=0.6, max_samples=0.6, min_samples_split=32, n_estimators=3800; total time=  25.1s
# [CV] END max_depth=8, max_features=0.6, max_samples=0.6, min_samples_split=32, n_estimators=3800; total time=  25.3s
# [CV] END max_depth=8, max_features=0.6, max_samples=0.6, min_samples_split=32, n_estimators=3800; total time=  25.0s
# [CV] END max_depth=2, max_features=0.6, max_samples=0.9, min_samples_split=16, n_estimators=4800; total time=  42.1s
# [CV] END max_depth=2, max_features=0.6, max_samples=0.9, min_samples_split=16, n_estimators=4800; total time=  41.8s
# [CV] END max_depth=2, max_features=0.6, max_samples=0.9, min_samples_split=16, n_estimators=4800; total time=  42.6s
# [CV] END max_depth=4, max_features=0.5, max_samples=0.4, min_samples_split=4, n_estimators=2100; total time=   7.7s
# [CV] END max_depth=4, max_features=0.5, max_samples=0.4, min_samples_split=4, n_estimators=2100; total time=   7.8s
# [CV] END max_depth=4, max_features=0.5, max_samples=0.4, min_samples_split=4, n_estimators=2100; total time=   7.9s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.8, min_samples_split=16, n_estimators=4600; total time=  29.6s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.8, min_samples_split=16, n_estimators=4600; total time=  29.7s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.8, min_samples_split=16, n_estimators=4600; total time=  29.5s
# [CV] END max_depth=4, max_features=0.6, max_samples=0.9, min_samples_split=16, n_estimators=4600; total time=  34.4s
# [CV] END max_depth=4, max_features=0.6, max_samples=0.9, min_samples_split=16, n_estimators=4600; total time=  34.3s
# [CV] END max_depth=4, max_features=0.6, max_samples=0.9, min_samples_split=16, n_estimators=4600; total time=  34.3s
# [CV] END max_depth=8, max_features=0.8, max_samples=0.6, min_samples_split=8, n_estimators=4900; total time=  34.4s
# [CV] END max_depth=8, max_features=0.8, max_samples=0.6, min_samples_split=8, n_estimators=4900; total time=  34.5s
# [CV] END max_depth=8, max_features=0.8, max_samples=0.6, min_samples_split=8, n_estimators=4900; total time=  34.3s
# [CV] END max_depth=8, max_features=0.7, max_samples=1.0, min_samples_split=8, n_estimators=3500; total time=  36.8s
# [CV] END max_depth=8, max_features=0.7, max_samples=1.0, min_samples_split=8, n_estimators=3500; total time=  36.8s
# [CV] END max_depth=8, max_features=0.7, max_samples=1.0, min_samples_split=8, n_estimators=3500; total time=  36.6s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.6, min_samples_split=32, n_estimators=4600; total time=  35.9s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.6, min_samples_split=32, n_estimators=4600; total time=  36.2s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.6, min_samples_split=32, n_estimators=4600; total time=  36.3s
# [CV] END max_depth=8, max_features=0.9, max_samples=0.4, min_samples_split=2, n_estimators=2900; total time=  14.8s
# [CV] END max_depth=8, max_features=0.9, max_samples=0.4, min_samples_split=2, n_estimators=2900; total time=  14.9s
# [CV] END max_depth=8, max_features=0.9, max_samples=0.4, min_samples_split=2, n_estimators=2900; total time=  15.0s
# [CV] END max_depth=2, max_features=0.8, max_samples=0.4, min_samples_split=4, n_estimators=2400; total time=  10.0s
# [CV] END max_depth=2, max_features=0.8, max_samples=0.4, min_samples_split=4, n_estimators=2400; total time=  10.3s
# [CV] END max_depth=2, max_features=0.8, max_samples=0.4, min_samples_split=4, n_estimators=2400; total time=  10.2s
# [CV] END max_depth=2, max_features=0.5, max_samples=0.7, min_samples_split=8, n_estimators=3600; total time=  25.2s
# [CV] END max_depth=2, max_features=0.5, max_samples=0.7, min_samples_split=8, n_estimators=3600; total time=  25.6s
# [CV] END max_depth=2, max_features=0.5, max_samples=0.7, min_samples_split=8, n_estimators=3600; total time=  25.3s
# [CV] END max_depth=16, max_features=0.9, max_samples=0.4, min_samples_split=2, n_estimators=2100; total time=  18.1s
# [CV] END max_depth=16, max_features=0.9, max_samples=0.4, min_samples_split=2, n_estimators=2100; total time=  17.7s
# [CV] END max_depth=16, max_features=0.9, max_samples=0.4, min_samples_split=2, n_estimators=2100; total time=  17.8s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.4, min_samples_split=8, n_estimators=3500; total time=  12.5s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.4, min_samples_split=8, n_estimators=3500; total time=  12.6s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.4, min_samples_split=8, n_estimators=3500; total time=  12.5s
# [CV] END max_depth=16, max_features=0.7, max_samples=0.8, min_samples_split=4, n_estimators=4400; total time=  54.9s
# [CV] END max_depth=16, max_features=0.7, max_samples=0.8, min_samples_split=4, n_estimators=4400; total time=  55.0s
# [CV] END max_depth=16, max_features=0.7, max_samples=0.8, min_samples_split=4, n_estimators=4400; total time=  55.0s
# [CV] END max_depth=4, max_features=0.8, max_samples=0.9, min_samples_split=8, n_estimators=1800; total time=  14.0s
# [CV] END max_depth=4, max_features=0.8, max_samples=0.9, min_samples_split=8, n_estimators=1800; total time=  13.9s
# [CV] END max_depth=4, max_features=0.8, max_samples=0.9, min_samples_split=8, n_estimators=1800; total time=  13.8s
# [CV] END max_depth=2, max_features=1.0, max_samples=1.0, min_samples_split=8, n_estimators=2400; total time=  23.6s
# [CV] END max_depth=2, max_features=1.0, max_samples=1.0, min_samples_split=8, n_estimators=2400; total time=  23.4s
# [CV] END max_depth=2, max_features=1.0, max_samples=1.0, min_samples_split=8, n_estimators=2400; total time=  23.6s
# [CV] END max_depth=16, max_features=0.9, max_samples=0.6, min_samples_split=4, n_estimators=4800; total time=  54.3s
# [CV] END max_depth=16, max_features=0.9, max_samples=0.6, min_samples_split=4, n_estimators=4800; total time=  54.8s
# [CV] END max_depth=16, max_features=0.9, max_samples=0.6, min_samples_split=4, n_estimators=4800; total time=  56.2s
# [CV] END max_depth=16, max_features=0.7, max_samples=0.8, min_samples_split=32, n_estimators=3200; total time=  37.3s
# [CV] END max_depth=16, max_features=0.7, max_samples=0.8, min_samples_split=32, n_estimators=3200; total time=  37.5s
# [CV] END max_depth=16, max_features=0.7, max_samples=0.8, min_samples_split=32, n_estimators=3200; total time=  37.3s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.5, min_samples_split=16, n_estimators=2900; total time=  14.3s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.5, min_samples_split=16, n_estimators=2900; total time=  14.5s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.5, min_samples_split=16, n_estimators=2900; total time=  14.1s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.4, min_samples_split=32, n_estimators=2200; total time=   8.1s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.4, min_samples_split=32, n_estimators=2200; total time=   8.0s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.4, min_samples_split=32, n_estimators=2200; total time=   8.0s
# [CV] END max_depth=2, max_features=0.5, max_samples=0.4, min_samples_split=2, n_estimators=2600; total time=  11.1s
# [CV] END max_depth=2, max_features=0.5, max_samples=0.4, min_samples_split=2, n_estimators=2600; total time=  11.1s
# [CV] END max_depth=2, max_features=0.5, max_samples=0.4, min_samples_split=2, n_estimators=2600; total time=  11.1s
# [CV] END max_depth=2, max_features=0.5, max_samples=0.6, min_samples_split=2, n_estimators=3100; total time=  18.8s
# [CV] END max_depth=2, max_features=0.5, max_samples=0.6, min_samples_split=2, n_estimators=3100; total time=  19.1s
# [CV] END max_depth=2, max_features=0.5, max_samples=0.6, min_samples_split=2, n_estimators=3100; total time=  18.9s
# [CV] END max_depth=4, max_features=0.6, max_samples=0.8, min_samples_split=4, n_estimators=3100; total time=  21.0s
# [CV] END max_depth=4, max_features=0.6, max_samples=0.8, min_samples_split=4, n_estimators=3100; total time=  20.9s
# [CV] END max_depth=4, max_features=0.6, max_samples=0.8, min_samples_split=4, n_estimators=3100; total time=  20.8s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.4, min_samples_split=2, n_estimators=1700; total time=   7.1s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.4, min_samples_split=2, n_estimators=1700; total time=   7.2s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.4, min_samples_split=2, n_estimators=1700; total time=   7.2s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.5, min_samples_split=16, n_estimators=3400; total time=  14.7s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.5, min_samples_split=16, n_estimators=3400; total time=  14.7s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.5, min_samples_split=16, n_estimators=3400; total time=  14.8s
# [CV] END max_depth=16, max_features=1.0, max_samples=0.6, min_samples_split=4, n_estimators=1400; total time=  16.9s
# [CV] END max_depth=16, max_features=1.0, max_samples=0.6, min_samples_split=4, n_estimators=1400; total time=  16.8s
# [CV] END max_depth=16, max_features=1.0, max_samples=0.6, min_samples_split=4, n_estimators=1400; total time=  16.7s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.9, min_samples_split=32, n_estimators=1400; total time=  10.0s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.9, min_samples_split=32, n_estimators=1400; total time=  10.1s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.9, min_samples_split=32, n_estimators=1400; total time=  10.1s
# [CV] END max_depth=8, max_features=0.9, max_samples=0.5, min_samples_split=16, n_estimators=3000; total time=  18.7s
# [CV] END max_depth=8, max_features=0.9, max_samples=0.5, min_samples_split=16, n_estimators=3000; total time=  18.8s
# [CV] END max_depth=8, max_features=0.9, max_samples=0.5, min_samples_split=16, n_estimators=3000; total time=  18.5s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.4, min_samples_split=8, n_estimators=3900; total time=  21.1s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.4, min_samples_split=8, n_estimators=3900; total time=  21.1s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.4, min_samples_split=8, n_estimators=3900; total time=  21.1s
# [CV] END max_depth=16, max_features=0.6, max_samples=0.8, min_samples_split=16, n_estimators=3500; total time=  40.0s
# [CV] END max_depth=16, max_features=0.6, max_samples=0.8, min_samples_split=16, n_estimators=3500; total time=  39.7s
# [CV] END max_depth=16, max_features=0.6, max_samples=0.8, min_samples_split=16, n_estimators=3500; total time=  39.4s
# [CV] END max_depth=4, max_features=0.7, max_samples=0.9, min_samples_split=2, n_estimators=3200; total time=  24.2s
# [CV] END max_depth=4, max_features=0.7, max_samples=0.9, min_samples_split=2, n_estimators=3200; total time=  24.3s
# [CV] END max_depth=4, max_features=0.7, max_samples=0.9, min_samples_split=2, n_estimators=3200; total time=  24.2s
# [CV] END max_depth=2, max_features=0.5, max_samples=0.9, min_samples_split=32, n_estimators=3000; total time=  26.5s
# [CV] END max_depth=2, max_features=0.5, max_samples=0.9, min_samples_split=32, n_estimators=3000; total time=  26.6s
# [CV] END max_depth=2, max_features=0.5, max_samples=0.9, min_samples_split=32, n_estimators=3000; total time=  26.6s
# [CV] END max_depth=8, max_features=0.6, max_samples=1.0, min_samples_split=4, n_estimators=4000; total time=  40.2s
# [CV] END max_depth=8, max_features=0.6, max_samples=1.0, min_samples_split=4, n_estimators=4000; total time=  40.4s
# [CV] END max_depth=8, max_features=0.6, max_samples=1.0, min_samples_split=4, n_estimators=4000; total time=  39.8s
# [CV] END max_depth=2, max_features=0.9, max_samples=0.4, min_samples_split=32, n_estimators=4600; total time=  19.5s
# [CV] END max_depth=2, max_features=0.9, max_samples=0.4, min_samples_split=32, n_estimators=4600; total time=  19.7s
# [CV] END max_depth=2, max_features=0.9, max_samples=0.4, min_samples_split=32, n_estimators=4600; total time=  20.0s
# [CV] END max_depth=8, max_features=0.9, max_samples=0.5, min_samples_split=16, n_estimators=1700; total time=  10.6s
# [CV] END max_depth=8, max_features=0.9, max_samples=0.5, min_samples_split=16, n_estimators=1700; total time=  10.7s
# [CV] END max_depth=8, max_features=0.9, max_samples=0.5, min_samples_split=16, n_estimators=1700; total time=  10.6s
# [CV] END max_depth=2, max_features=1.0, max_samples=0.4, min_samples_split=8, n_estimators=4100; total time=  17.5s
# [CV] END max_depth=2, max_features=1.0, max_samples=0.4, min_samples_split=8, n_estimators=4100; total time=  17.4s
# [CV] END max_depth=2, max_features=1.0, max_samples=0.4, min_samples_split=8, n_estimators=4100; total time=  17.5s
# [CV] END max_depth=8, max_features=0.5, max_samples=0.5, min_samples_split=8, n_estimators=3500; total time=  18.4s
# [CV] END max_depth=8, max_features=0.5, max_samples=0.5, min_samples_split=8, n_estimators=3500; total time=  18.5s
# [CV] END max_depth=8, max_features=0.5, max_samples=0.5, min_samples_split=8, n_estimators=3500; total time=  18.6s
# [CV] END max_depth=2, max_features=0.9, max_samples=0.8, min_samples_split=32, n_estimators=2100; total time=  16.6s
# [CV] END max_depth=2, max_features=0.9, max_samples=0.8, min_samples_split=32, n_estimators=2100; total time=  16.5s
# [CV] END max_depth=2, max_features=0.9, max_samples=0.8, min_samples_split=32, n_estimators=2100; total time=  16.4s
# [CV] END max_depth=2, max_features=0.6, max_samples=0.7, min_samples_split=2, n_estimators=1300; total time=   9.2s
# [CV] END max_depth=2, max_features=0.6, max_samples=0.7, min_samples_split=2, n_estimators=1300; total time=   9.1s
# [CV] END max_depth=2, max_features=0.6, max_samples=0.7, min_samples_split=2, n_estimators=1300; total time=   9.0s
# [CV] END max_depth=2, max_features=1.0, max_samples=1.0, min_samples_split=8, n_estimators=4800; total time=  46.8s
# [CV] END max_depth=2, max_features=1.0, max_samples=1.0, min_samples_split=8, n_estimators=4800; total time=  47.2s
# [CV] END max_depth=2, max_features=1.0, max_samples=1.0, min_samples_split=8, n_estimators=4800; total time=  47.3s
# [CV] END max_depth=2, max_features=0.5, max_samples=0.5, min_samples_split=8, n_estimators=1900; total time=   9.9s
# [CV] END max_depth=2, max_features=0.5, max_samples=0.5, min_samples_split=8, n_estimators=1900; total time=  10.0s
# [CV] END max_depth=2, max_features=0.5, max_samples=0.5, min_samples_split=8, n_estimators=1900; total time=   9.8s
# [CV] END max_depth=16, max_features=0.6, max_samples=1.0, min_samples_split=8, n_estimators=4100; total time=  58.2s
# [CV] END max_depth=16, max_features=0.6, max_samples=1.0, min_samples_split=8, n_estimators=4100; total time=  58.5s
# [CV] END max_depth=16, max_features=0.6, max_samples=1.0, min_samples_split=8, n_estimators=4100; total time=  58.3s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.7, min_samples_split=8, n_estimators=4400; total time=  29.3s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.7, min_samples_split=8, n_estimators=4400; total time=  29.9s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.7, min_samples_split=8, n_estimators=4400; total time=  29.1s
# [CV] END max_depth=4, max_features=0.5, max_samples=0.8, min_samples_split=4, n_estimators=3000; total time=  19.8s
# [CV] END max_depth=4, max_features=0.5, max_samples=0.8, min_samples_split=4, n_estimators=3000; total time=  19.7s
# [CV] END max_depth=4, max_features=0.5, max_samples=0.8, min_samples_split=4, n_estimators=3000; total time=  19.7s
# [CV] END max_depth=8, max_features=0.5, max_samples=0.8, min_samples_split=2, n_estimators=1300; total time=  10.4s
# [CV] END max_depth=8, max_features=0.5, max_samples=0.8, min_samples_split=2, n_estimators=1300; total time=  10.4s
# [CV] END max_depth=8, max_features=0.5, max_samples=0.8, min_samples_split=2, n_estimators=1300; total time=  10.4s
# [CV] END max_depth=4, max_features=0.9, max_samples=0.9, min_samples_split=16, n_estimators=4000; total time=  31.3s
# [CV] END max_depth=4, max_features=0.9, max_samples=0.9, min_samples_split=16, n_estimators=4000; total time=  31.3s
# [CV] END max_depth=4, max_features=0.9, max_samples=0.9, min_samples_split=16, n_estimators=4000; total time=  31.3s
# [CV] END max_depth=2, max_features=0.7, max_samples=0.7, min_samples_split=8, n_estimators=3800; total time=  26.6s
# [CV] END max_depth=2, max_features=0.7, max_samples=0.7, min_samples_split=8, n_estimators=3800; total time=  26.4s
# [CV] END max_depth=2, max_features=0.7, max_samples=0.7, min_samples_split=8, n_estimators=3800; total time=  26.4s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.4, min_samples_split=2, n_estimators=2900; total time=  11.6s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.4, min_samples_split=2, n_estimators=2900; total time=  11.4s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.4, min_samples_split=2, n_estimators=2900; total time=  11.6s
# [CV] END max_depth=4, max_features=0.7, max_samples=0.7, min_samples_split=2, n_estimators=2600; total time=  15.9s
# [CV] END max_depth=4, max_features=0.7, max_samples=0.7, min_samples_split=2, n_estimators=2600; total time=  15.9s
# [CV] END max_depth=4, max_features=0.7, max_samples=0.7, min_samples_split=2, n_estimators=2600; total time=  15.9s
# [CV] END max_depth=8, max_features=0.6, max_samples=0.4, min_samples_split=32, n_estimators=4200; total time=  19.3s
# [CV] END max_depth=8, max_features=0.6, max_samples=0.4, min_samples_split=32, n_estimators=4200; total time=  19.2s
# [CV] END max_depth=8, max_features=0.6, max_samples=0.4, min_samples_split=32, n_estimators=4200; total time=  19.1s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.7, min_samples_split=32, n_estimators=4000; total time=  26.9s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.7, min_samples_split=32, n_estimators=4000; total time=  27.0s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.7, min_samples_split=32, n_estimators=4000; total time=  26.5s
# [CV] END max_depth=16, max_features=1.0, max_samples=0.7, min_samples_split=4, n_estimators=3500; total time=  47.8s
# [CV] END max_depth=16, max_features=1.0, max_samples=0.7, min_samples_split=4, n_estimators=3500; total time=  47.8s
# [CV] END max_depth=16, max_features=1.0, max_samples=0.7, min_samples_split=4, n_estimators=3500; total time=  47.7s
# [CV] END max_depth=16, max_features=0.9, max_samples=0.7, min_samples_split=16, n_estimators=3600; total time=  44.2s
# [CV] END max_depth=16, max_features=0.9, max_samples=0.7, min_samples_split=16, n_estimators=3600; total time=  44.2s
# [CV] END max_depth=16, max_features=0.9, max_samples=0.7, min_samples_split=16, n_estimators=3600; total time=  44.1s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.7, min_samples_split=8, n_estimators=3700; total time=  24.7s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.7, min_samples_split=8, n_estimators=3700; total time=  24.8s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.7, min_samples_split=8, n_estimators=3700; total time=  24.9s
# [CV] END max_depth=2, max_features=0.8, max_samples=0.7, min_samples_split=4, n_estimators=4200; total time=  28.9s
# [CV] END max_depth=2, max_features=0.8, max_samples=0.7, min_samples_split=4, n_estimators=4200; total time=  29.1s
# [CV] END max_depth=2, max_features=0.8, max_samples=0.7, min_samples_split=4, n_estimators=4200; total time=  29.2s
# [CV] END max_depth=8, max_features=0.4, max_samples=1.0, min_samples_split=16, n_estimators=3200; total time=  28.6s
# [CV] END max_depth=8, max_features=0.4, max_samples=1.0, min_samples_split=16, n_estimators=3200; total time=  29.0s
# [CV] END max_depth=8, max_features=0.4, max_samples=1.0, min_samples_split=16, n_estimators=3200; total time=  28.8s
# [CV] END max_depth=4, max_features=0.5, max_samples=0.6, min_samples_split=2, n_estimators=3000; total time=  15.7s
# [CV] END max_depth=4, max_features=0.5, max_samples=0.6, min_samples_split=2, n_estimators=3000; total time=  15.6s
# [CV] END max_depth=4, max_features=0.5, max_samples=0.6, min_samples_split=2, n_estimators=3000; total time=  15.7s
# [CV] END max_depth=16, max_features=0.5, max_samples=0.6, min_samples_split=32, n_estimators=2200; total time=  18.4s
# [CV] END max_depth=16, max_features=0.5, max_samples=0.6, min_samples_split=32, n_estimators=2200; total time=  18.6s
# [CV] END max_depth=16, max_features=0.5, max_samples=0.6, min_samples_split=32, n_estimators=2200; total time=  18.4s
# [CV] END max_depth=16, max_features=0.9, max_samples=0.9, min_samples_split=8, n_estimators=2800; total time=  43.9s
# [CV] END max_depth=16, max_features=0.9, max_samples=0.9, min_samples_split=8, n_estimators=2800; total time=  44.5s
# [CV] END max_depth=16, max_features=0.9, max_samples=0.9, min_samples_split=8, n_estimators=2800; total time=  43.8s
# [CV] END max_depth=8, max_features=0.8, max_samples=1.0, min_samples_split=4, n_estimators=3200; total time=  35.0s
# [CV] END max_depth=8, max_features=0.8, max_samples=1.0, min_samples_split=4, n_estimators=3200; total time=  35.1s
# [CV] END max_depth=8, max_features=0.8, max_samples=1.0, min_samples_split=4, n_estimators=3200; total time=  35.3s
# [CV] END max_depth=16, max_features=0.9, max_samples=0.5, min_samples_split=8, n_estimators=3800; total time=  36.4s
# [CV] END max_depth=16, max_features=0.9, max_samples=0.5, min_samples_split=8, n_estimators=3800; total time=  36.3s
# [CV] END max_depth=16, max_features=0.9, max_samples=0.5, min_samples_split=8, n_estimators=3800; total time=  37.2s
# [CV] END max_depth=16, max_features=0.8, max_samples=0.5, min_samples_split=4, n_estimators=4200; total time=  40.5s
# [CV] END max_depth=16, max_features=0.8, max_samples=0.5, min_samples_split=4, n_estimators=4200; total time=  39.1s
# [CV] END max_depth=16, max_features=0.8, max_samples=0.5, min_samples_split=4, n_estimators=4200; total time=  39.3s
# [CV] END max_depth=8, max_features=0.6, max_samples=0.9, min_samples_split=4, n_estimators=2500; total time=  23.1s
# [CV] END max_depth=8, max_features=0.6, max_samples=0.9, min_samples_split=4, n_estimators=2500; total time=  23.0s
# [CV] END max_depth=8, max_features=0.6, max_samples=0.9, min_samples_split=4, n_estimators=2500; total time=  22.9s
# [CV] END max_depth=8, max_features=0.7, max_samples=0.6, min_samples_split=4, n_estimators=1400; total time=   9.8s
# [CV] END max_depth=8, max_features=0.7, max_samples=0.6, min_samples_split=4, n_estimators=1400; total time=   9.6s
# [CV] END max_depth=8, max_features=0.7, max_samples=0.6, min_samples_split=4, n_estimators=1400; total time=   9.8s
# [CV] END max_depth=16, max_features=0.7, max_samples=0.7, min_samples_split=2, n_estimators=3600; total time=  41.1s
# [CV] END max_depth=16, max_features=0.7, max_samples=0.7, min_samples_split=2, n_estimators=3600; total time=  41.1s
# [CV] END max_depth=16, max_features=0.7, max_samples=0.7, min_samples_split=2, n_estimators=3600; total time=  40.9s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.4, min_samples_split=32, n_estimators=1600; total time=   6.7s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.4, min_samples_split=32, n_estimators=1600; total time=   6.7s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.4, min_samples_split=32, n_estimators=1600; total time=   6.8s
# [CV] END max_depth=8, max_features=0.7, max_samples=0.5, min_samples_split=8, n_estimators=2300; total time=  13.3s
# [CV] END max_depth=8, max_features=0.7, max_samples=0.5, min_samples_split=8, n_estimators=2300; total time=  13.3s
# [CV] END max_depth=8, max_features=0.7, max_samples=0.5, min_samples_split=8, n_estimators=2300; total time=  13.2s
# [CV] END max_depth=2, max_features=1.0, max_samples=0.4, min_samples_split=8, n_estimators=3100; total time=  13.3s
# [CV] END max_depth=2, max_features=1.0, max_samples=0.4, min_samples_split=8, n_estimators=3100; total time=  13.4s
# [CV] END max_depth=2, max_features=1.0, max_samples=0.4, min_samples_split=8, n_estimators=3100; total time=  13.4s
# [CV] END max_depth=8, max_features=0.7, max_samples=0.7, min_samples_split=32, n_estimators=4100; total time=  31.8s
# [CV] END max_depth=8, max_features=0.7, max_samples=0.7, min_samples_split=32, n_estimators=4100; total time=  32.0s
# [CV] END max_depth=8, max_features=0.7, max_samples=0.7, min_samples_split=32, n_estimators=4100; total time=  32.0s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.7, min_samples_split=2, n_estimators=1500; total time=   8.7s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.7, min_samples_split=2, n_estimators=1500; total time=   8.8s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.7, min_samples_split=2, n_estimators=1500; total time=   8.7s
# [CV] END max_depth=8, max_features=0.8, max_samples=0.5, min_samples_split=32, n_estimators=4300; total time=  25.3s
# [CV] END max_depth=8, max_features=0.8, max_samples=0.5, min_samples_split=32, n_estimators=4300; total time=  25.4s
# [CV] END max_depth=8, max_features=0.8, max_samples=0.5, min_samples_split=32, n_estimators=4300; total time=  25.3s
# [CV] END max_depth=8, max_features=0.5, max_samples=0.5, min_samples_split=8, n_estimators=1000; total time=   5.4s
# [CV] END max_depth=8, max_features=0.5, max_samples=0.5, min_samples_split=8, n_estimators=1000; total time=   5.4s
# [CV] END max_depth=8, max_features=0.5, max_samples=0.5, min_samples_split=8, n_estimators=1000; total time=   5.5s
# [CV] END max_depth=4, max_features=0.7, max_samples=0.8, min_samples_split=8, n_estimators=2500; total time=  17.3s
# [CV] END max_depth=4, max_features=0.7, max_samples=0.8, min_samples_split=8, n_estimators=2500; total time=  17.2s
# [CV] END max_depth=4, max_features=0.7, max_samples=0.8, min_samples_split=8, n_estimators=2500; total time=  17.4s
# [CV] END max_depth=16, max_features=0.4, max_samples=0.8, min_samples_split=16, n_estimators=3900; total time=  38.8s
# [CV] END max_depth=16, max_features=0.4, max_samples=0.8, min_samples_split=16, n_estimators=3900; total time=  39.0s
# [CV] END max_depth=16, max_features=0.4, max_samples=0.8, min_samples_split=16, n_estimators=3900; total time=  38.9s
# [CV] END max_depth=4, max_features=0.5, max_samples=1.0, min_samples_split=32, n_estimators=2100; total time=  16.9s
# [CV] END max_depth=4, max_features=0.5, max_samples=1.0, min_samples_split=32, n_estimators=2100; total time=  16.7s
# [CV] END max_depth=4, max_features=0.5, max_samples=1.0, min_samples_split=32, n_estimators=2100; total time=  16.7s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.5, min_samples_split=16, n_estimators=1000; total time=   6.5s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.5, min_samples_split=16, n_estimators=1000; total time=   6.7s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.5, min_samples_split=16, n_estimators=1000; total time=   6.5s
# [CV] END max_depth=16, max_features=0.6, max_samples=0.5, min_samples_split=2, n_estimators=3400; total time=  27.9s
# [CV] END max_depth=16, max_features=0.6, max_samples=0.5, min_samples_split=2, n_estimators=3400; total time=  27.6s
# [CV] END max_depth=16, max_features=0.6, max_samples=0.5, min_samples_split=2, n_estimators=3400; total time=  28.0s
# [CV] END max_depth=2, max_features=0.5, max_samples=1.0, min_samples_split=4, n_estimators=4800; total time=  47.0s
# [CV] END max_depth=2, max_features=0.5, max_samples=1.0, min_samples_split=4, n_estimators=4800; total time=  46.7s
# [CV] END max_depth=2, max_features=0.5, max_samples=1.0, min_samples_split=4, n_estimators=4800; total time=  46.6s
# [CV] END max_depth=16, max_features=1.0, max_samples=0.6, min_samples_split=8, n_estimators=1900; total time=  22.3s
# [CV] END max_depth=16, max_features=1.0, max_samples=0.6, min_samples_split=8, n_estimators=1900; total time=  22.4s
# [CV] END max_depth=16, max_features=1.0, max_samples=0.6, min_samples_split=8, n_estimators=1900; total time=  22.5s
# [CV] END max_depth=2, max_features=0.7, max_samples=0.4, min_samples_split=16, n_estimators=3100; total time=  13.3s
# [CV] END max_depth=2, max_features=0.7, max_samples=0.4, min_samples_split=16, n_estimators=3100; total time=  13.1s
# [CV] END max_depth=2, max_features=0.7, max_samples=0.4, min_samples_split=16, n_estimators=3100; total time=  13.2s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.6, min_samples_split=16, n_estimators=1500; total time=   8.6s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.6, min_samples_split=16, n_estimators=1500; total time=   8.7s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.6, min_samples_split=16, n_estimators=1500; total time=   8.7s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.5, min_samples_split=4, n_estimators=4200; total time=  18.2s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.5, min_samples_split=4, n_estimators=4200; total time=  18.4s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.5, min_samples_split=4, n_estimators=4200; total time=  18.2s
# ...
# [CV] END max_depth=4, max_features=0.4, max_samples=0.6, min_samples_split=4, n_estimators=3400; total time=  17.4s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.6, min_samples_split=4, n_estimators=3400; total time=  17.3s
# [CV] END max_depth=16, max_features=0.6, max_samples=0.6, min_samples_split=8, n_estimators=3200; total time=  29.3s
# [CV] END max_depth=16, max_features=0.6, max_samples=0.6, min_samples_split=8, n_estimators=3200; total time=  29.3s
# [CV] END max_depth=16, max_features=0.6, max_samples=0.6, min_samples_split=8, n_estimators=3200; total time=  29.3s
# [CV] END max_depth=4, max_features=0.8, max_samples=1.0, min_samples_split=2, n_estimators=4500; total time=  37.9s
# [CV] END max_depth=4, max_features=0.8, max_samples=1.0, min_samples_split=2, n_estimators=4500; total time=  37.7s
# [CV] END max_depth=4, max_features=0.8, max_samples=1.0, min_samples_split=2, n_estimators=4500; total time=  37.7s
# [CV] END max_depth=2, max_features=0.6, max_samples=0.4, min_samples_split=16, n_estimators=1800; total time=   7.8s
# [CV] END max_depth=2, max_features=0.6, max_samples=0.4, min_samples_split=16, n_estimators=1800; total time=   7.8s
# [CV] END max_depth=2, max_features=0.6, max_samples=0.4, min_samples_split=16, n_estimators=1800; total time=   7.8s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.6, min_samples_split=4, n_estimators=3300; total time=  19.4s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.6, min_samples_split=4, n_estimators=3300; total time=  19.6s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.6, min_samples_split=4, n_estimators=3300; total time=  19.4s
# [CV] END max_depth=4, max_features=0.5, max_samples=0.6, min_samples_split=32, n_estimators=4900; total time=  25.7s
# [CV] END max_depth=4, max_features=0.5, max_samples=0.6, min_samples_split=32, n_estimators=4900; total time=  25.6s
# [CV] END max_depth=4, max_features=0.5, max_samples=0.6, min_samples_split=32, n_estimators=4900; total time=  25.6s
# [CV] END max_depth=4, max_features=0.8, max_samples=0.8, min_samples_split=16, n_estimators=1000; total time=   7.0s
# [CV] END max_depth=4, max_features=0.8, max_samples=0.8, min_samples_split=16, n_estimators=1000; total time=   6.9s
# [CV] END max_depth=4, max_features=0.8, max_samples=0.8, min_samples_split=16, n_estimators=1000; total time=   7.0s
# [CV] END max_depth=16, max_features=0.8, max_samples=0.4, min_samples_split=16, n_estimators=3000; total time=  21.4s
# [CV] END max_depth=16, max_features=0.8, max_samples=0.4, min_samples_split=16, n_estimators=3000; total time=  21.3s
# [CV] END max_depth=16, max_features=0.8, max_samples=0.4, min_samples_split=16, n_estimators=3000; total time=  21.2s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.6, min_samples_split=32, n_estimators=2400; total time=  18.6s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.6, min_samples_split=32, n_estimators=2400; total time=  19.1s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.6, min_samples_split=32, n_estimators=2400; total time=  18.7s
# [CV] END max_depth=4, max_features=0.8, max_samples=0.9, min_samples_split=2, n_estimators=1200; total time=   9.2s
# [CV] END max_depth=4, max_features=0.8, max_samples=0.9, min_samples_split=2, n_estimators=1200; total time=   9.4s
# [CV] END max_depth=4, max_features=0.8, max_samples=0.9, min_samples_split=2, n_estimators=1200; total time=   9.4s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.6, min_samples_split=4, n_estimators=1400; total time=  10.9s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.6, min_samples_split=4, n_estimators=1400; total time=  11.0s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.6, min_samples_split=4, n_estimators=1400; total time=  11.1s
# [CV] END max_depth=8, max_features=0.5, max_samples=1.0, min_samples_split=8, n_estimators=3500; total time=  33.4s
# [CV] END max_depth=8, max_features=0.5, max_samples=1.0, min_samples_split=8, n_estimators=3500; total time=  33.2s
# [CV] END max_depth=8, max_features=0.5, max_samples=1.0, min_samples_split=8, n_estimators=3500; total time=  33.2s
# [CV] END max_depth=4, max_features=0.4, max_samples=1.0, min_samples_split=16, n_estimators=3800; total time=  29.9s
# [CV] END max_depth=4, max_features=0.4, max_samples=1.0, min_samples_split=16, n_estimators=3800; total time=  30.0s
# [CV] END max_depth=4, max_features=0.4, max_samples=1.0, min_samples_split=16, n_estimators=3800; total time=  29.9s
# [CV] END max_depth=4, max_features=0.7, max_samples=0.6, min_samples_split=32, n_estimators=1300; total time=   7.1s
# [CV] END max_depth=4, max_features=0.7, max_samples=0.6, min_samples_split=32, n_estimators=1300; total time=   7.1s
# [CV] END max_depth=4, max_features=0.7, max_samples=0.6, min_samples_split=32, n_estimators=1300; total time=   7.1s
# [CV] END max_depth=8, max_features=0.6, max_samples=1.0, min_samples_split=32, n_estimators=2300; total time=  23.1s
# [CV] END max_depth=8, max_features=0.6, max_samples=1.0, min_samples_split=32, n_estimators=2300; total time=  22.9s
# [CV] END max_depth=8, max_features=0.6, max_samples=1.0, min_samples_split=32, n_estimators=2300; total time=  23.0s
# [CV] END max_depth=16, max_features=0.5, max_samples=1.0, min_samples_split=2, n_estimators=4600; total time= 1.0min
# [CV] END max_depth=16, max_features=0.5, max_samples=1.0, min_samples_split=2, n_estimators=4600; total time= 1.0min
# [CV] END max_depth=16, max_features=0.5, max_samples=1.0, min_samples_split=2, n_estimators=4600; total time= 1.0min
# [CV] END max_depth=8, max_features=1.0, max_samples=0.9, min_samples_split=4, n_estimators=1400; total time=  15.7s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.9, min_samples_split=4, n_estimators=1400; total time=  15.7s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.9, min_samples_split=4, n_estimators=1400; total time=  15.7s
# [CV] END max_depth=16, max_features=0.5, max_samples=0.9, min_samples_split=8, n_estimators=3200; total time=  38.4s
# [CV] END max_depth=16, max_features=0.5, max_samples=0.9, min_samples_split=8, n_estimators=3200; total time=  38.4s
# [CV] END max_depth=16, max_features=0.5, max_samples=0.9, min_samples_split=8, n_estimators=3200; total time=  38.6s
# [CV] END max_depth=4, max_features=0.5, max_samples=0.9, min_samples_split=2, n_estimators=1400; total time=  10.3s
# [CV] END max_depth=4, max_features=0.5, max_samples=0.9, min_samples_split=2, n_estimators=1400; total time=  10.3s
# [CV] END max_depth=4, max_features=0.5, max_samples=0.9, min_samples_split=2, n_estimators=1400; total time=  10.2s
# [CV] END max_depth=2, max_features=0.6, max_samples=0.8, min_samples_split=8, n_estimators=2300; total time=  18.6s
# [CV] END max_depth=2, max_features=0.6, max_samples=0.8, min_samples_split=8, n_estimators=2300; total time=  18.4s
# [CV] END max_depth=2, max_features=0.6, max_samples=0.8, min_samples_split=8, n_estimators=2300; total time=  18.1s
# [CV] END max_depth=2, max_features=0.4, max_samples=0.5, min_samples_split=4, n_estimators=1600; total time=   8.5s
# [CV] END max_depth=2, max_features=0.4, max_samples=0.5, min_samples_split=4, n_estimators=1600; total time=   8.4s
# [CV] END max_depth=2, max_features=0.4, max_samples=0.5, min_samples_split=4, n_estimators=1600; total time=   8.4s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.5, min_samples_split=2, n_estimators=2300; total time=  10.1s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.5, min_samples_split=2, n_estimators=2300; total time=   9.9s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.5, min_samples_split=2, n_estimators=2300; total time=  10.1s
# [CV] END max_depth=8, max_features=0.4, max_samples=1.0, min_samples_split=4, n_estimators=1500; total time=  13.5s
# [CV] END max_depth=8, max_features=0.4, max_samples=1.0, min_samples_split=4, n_estimators=1500; total time=  13.4s
# [CV] END max_depth=8, max_features=0.4, max_samples=1.0, min_samples_split=4, n_estimators=1500; total time=  13.4s
# [CV] END max_depth=16, max_features=0.9, max_samples=0.9, min_samples_split=8, n_estimators=2000; total time=  31.0s
# [CV] END max_depth=16, max_features=0.9, max_samples=0.9, min_samples_split=8, n_estimators=2000; total time=  31.2s
# [CV] END max_depth=16, max_features=0.9, max_samples=0.9, min_samples_split=8, n_estimators=2000; total time=  31.1s
# [CV] END max_depth=16, max_features=0.4, max_samples=0.4, min_samples_split=32, n_estimators=4900; total time=  26.8s
# [CV] END max_depth=16, max_features=0.4, max_samples=0.4, min_samples_split=32, n_estimators=4900; total time=  27.0s
# [CV] END max_depth=16, max_features=0.4, max_samples=0.4, min_samples_split=32, n_estimators=4900; total time=  26.9s
# [CV] END max_depth=8, max_features=0.6, max_samples=0.9, min_samples_split=2, n_estimators=1500; total time=  13.8s
# [CV] END max_depth=8, max_features=0.6, max_samples=0.9, min_samples_split=2, n_estimators=1500; total time=  13.7s
# [CV] END max_depth=8, max_features=0.6, max_samples=0.9, min_samples_split=2, n_estimators=1500; total time=  13.9s
# [CV] END max_depth=16, max_features=0.6, max_samples=0.4, min_samples_split=32, n_estimators=4000; total time=  24.4s
# [CV] END max_depth=16, max_features=0.6, max_samples=0.4, min_samples_split=32, n_estimators=4000; total time=  24.6s
# [CV] END max_depth=16, max_features=0.6, max_samples=0.4, min_samples_split=32, n_estimators=4000; total time=  24.6s
# [CV] END max_depth=16, max_features=0.8, max_samples=0.7, min_samples_split=32, n_estimators=1900; total time=  21.5s
# [CV] END max_depth=16, max_features=0.8, max_samples=0.7, min_samples_split=32, n_estimators=1900; total time=  21.5s
# [CV] END max_depth=16, max_features=0.8, max_samples=0.7, min_samples_split=32, n_estimators=1900; total time=  21.6s
# [CV] END max_depth=2, max_features=0.8, max_samples=0.4, min_samples_split=2, n_estimators=1900; total time=   8.0s
# [CV] END max_depth=2, max_features=0.8, max_samples=0.4, min_samples_split=2, n_estimators=1900; total time=   8.2s
# [CV] END max_depth=2, max_features=0.8, max_samples=0.4, min_samples_split=2, n_estimators=1900; total time=   8.1s
# [CV] END max_depth=16, max_features=0.9, max_samples=0.8, min_samples_split=32, n_estimators=2300; total time=  30.8s
# [CV] END max_depth=16, max_features=0.9, max_samples=0.8, min_samples_split=32, n_estimators=2300; total time=  30.9s
# [CV] END max_depth=16, max_features=0.9, max_samples=0.8, min_samples_split=32, n_estimators=2300; total time=  31.1s
# [CV] END max_depth=4, max_features=0.9, max_samples=0.4, min_samples_split=8, n_estimators=3200; total time=  12.6s
# [CV] END max_depth=4, max_features=0.9, max_samples=0.4, min_samples_split=8, n_estimators=3200; total time=  12.5s
# [CV] END max_depth=4, max_features=0.9, max_samples=0.4, min_samples_split=8, n_estimators=3200; total time=  12.6s
# [CV] END max_depth=2, max_features=0.6, max_samples=0.4, min_samples_split=2, n_estimators=2500; total time=  10.6s
# [CV] END max_depth=2, max_features=0.6, max_samples=0.4, min_samples_split=2, n_estimators=2500; total time=  10.8s
# [CV] END max_depth=2, max_features=0.6, max_samples=0.4, min_samples_split=2, n_estimators=2500; total time=  10.7s
# [CV] END max_depth=8, max_features=0.6, max_samples=0.7, min_samples_split=32, n_estimators=4500; total time=  34.4s
# [CV] END max_depth=8, max_features=0.6, max_samples=0.7, min_samples_split=32, n_estimators=4500; total time=  33.2s
# [CV] END max_depth=8, max_features=0.6, max_samples=0.7, min_samples_split=32, n_estimators=4500; total time=  33.4s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.9, min_samples_split=32, n_estimators=3500; total time=  28.5s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.9, min_samples_split=32, n_estimators=3500; total time=  28.5s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.9, min_samples_split=32, n_estimators=3500; total time=  28.6s
# [CV] END max_depth=8, max_features=1.0, max_samples=1.0, min_samples_split=4, n_estimators=2200; total time=  26.5s
# [CV] END max_depth=8, max_features=1.0, max_samples=1.0, min_samples_split=4, n_estimators=2200; total time=  27.0s
# [CV] END max_depth=8, max_features=1.0, max_samples=1.0, min_samples_split=4, n_estimators=2200; total time=  26.8s
# [CV] END max_depth=8, max_features=0.6, max_samples=0.4, min_samples_split=4, n_estimators=4300; total time=  22.4s
# [CV] END max_depth=8, max_features=0.6, max_samples=0.4, min_samples_split=4, n_estimators=4300; total time=  18.9s
# [CV] END max_depth=8, max_features=0.6, max_samples=0.4, min_samples_split=4, n_estimators=4300; total time=  18.9s
# [CV] END max_depth=16, max_features=0.4, max_samples=0.4, min_samples_split=4, n_estimators=1300; total time=   7.6s
# [CV] END max_depth=16, max_features=0.4, max_samples=0.4, min_samples_split=4, n_estimators=1300; total time=   7.6s
# [CV] END max_depth=16, max_features=0.4, max_samples=0.4, min_samples_split=4, n_estimators=1300; total time=   7.6s
# [CV] END max_depth=16, max_features=0.9, max_samples=0.6, min_samples_split=8, n_estimators=1000; total time=  11.1s
# [CV] END max_depth=16, max_features=0.9, max_samples=0.6, min_samples_split=8, n_estimators=1000; total time=  11.0s
# [CV] END max_depth=16, max_features=0.9, max_samples=0.6, min_samples_split=8, n_estimators=1000; total time=  11.1s
# [CV] END max_depth=2, max_features=1.0, max_samples=0.5, min_samples_split=32, n_estimators=4100; total time=  21.5s
# [CV] END max_depth=2, max_features=1.0, max_samples=0.5, min_samples_split=32, n_estimators=4100; total time=  21.7s
# [CV] END max_depth=2, max_features=1.0, max_samples=0.5, min_samples_split=32, n_estimators=4100; total time=  21.5s
# [CV] END max_depth=16, max_features=0.4, max_samples=0.9, min_samples_split=8, n_estimators=4400; total time=  48.6s
# [CV] END max_depth=16, max_features=0.4, max_samples=0.9, min_samples_split=8, n_estimators=4400; total time=  48.4s
# [CV] END max_depth=16, max_features=0.4, max_samples=0.9, min_samples_split=8, n_estimators=4400; total time=  48.4s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.6, min_samples_split=4, n_estimators=3000; total time=  16.9s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.6, min_samples_split=4, n_estimators=3000; total time=  17.2s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.6, min_samples_split=4, n_estimators=3000; total time=  16.9s
# [CV] END max_depth=8, max_features=1.0, max_samples=1.0, min_samples_split=8, n_estimators=4800; total time=  55.5s
# [CV] END max_depth=8, max_features=1.0, max_samples=1.0, min_samples_split=8, n_estimators=4800; total time=  56.0s
# [CV] END max_depth=8, max_features=1.0, max_samples=1.0, min_samples_split=8, n_estimators=4800; total time=  55.0s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.7, min_samples_split=2, n_estimators=3200; total time=  20.4s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.7, min_samples_split=2, n_estimators=3200; total time=  20.7s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.7, min_samples_split=2, n_estimators=3200; total time=  20.6s
# [CV] END max_depth=4, max_features=0.8, max_samples=0.6, min_samples_split=4, n_estimators=1600; total time=   8.6s
# [CV] END max_depth=4, max_features=0.8, max_samples=0.6, min_samples_split=4, n_estimators=1600; total time=   8.6s
# [CV] END max_depth=4, max_features=0.8, max_samples=0.6, min_samples_split=4, n_estimators=1600; total time=   8.6s
# [CV] END max_depth=2, max_features=0.5, max_samples=0.8, min_samples_split=32, n_estimators=3600; total time=  29.3s
# [CV] END max_depth=2, max_features=0.5, max_samples=0.8, min_samples_split=32, n_estimators=3600; total time=  29.1s
# [CV] END max_depth=2, max_features=0.5, max_samples=0.8, min_samples_split=32, n_estimators=3600; total time=  29.0s
# [CV] END max_depth=8, max_features=0.7, max_samples=0.7, min_samples_split=32, n_estimators=1300; total time=   9.7s
# [CV] END max_depth=8, max_features=0.7, max_samples=0.7, min_samples_split=32, n_estimators=1300; total time=   9.8s
# [CV] END max_depth=8, max_features=0.7, max_samples=0.7, min_samples_split=32, n_estimators=1300; total time=   9.5s

# %%
CV_result = random_search.cv_results_

# %%
pd.DataFrame(CV_result).sort_values(by='rank_test_score', ascending=True).loc[:,:].head()

# %%
dump(random_search, '03_Results/RandomSearch500_5hyper_v2.joblib')

# %%
pd.DataFrame(CV_result).sort_values(by='rank_test_score', ascending=True).to_csv('03_Results/RandomSearch500_hyper_v2.csv')

# %% [markdown]
# ### Test Perfromance

# %%
random_search.best_params_

# %%
rf_reg_final =RandomForestRegressor(**random_search.best_params_)
rf_reg_final.fit(X_train, y_train)

# %%
# Predictions
y_pred = rf_reg_final.predict(X_test)

# %%
y_pred

# %%
r2_score(y_test, y_pred)
