# %% [markdown]
# # Hyperparameter Search

# %% [markdown]
# In V2 more hyperparameters are considered and larger range

# %%
# %pwd
# Out:
# '/home/rapids/notebooks/DP15/PyCode_v241111'

# %%
# %cd ..
# Out:
# /home/rapids/notebooks/DP15

# %% [markdown]
# ## Import Package

# %%
import cudf
from glob import glob
from joblib import dump, load
import numpy as np
import pandas as pd
import random
from cuml.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score, make_scorer, accuracy_score
from sklearn.model_selection import train_test_split, KFold, RandomizedSearchCV

# %%
import warnings

warnings.filterwarnings(
    "ignore", 
    message="To use pickling first train using float32 data to fit the estimator"
)

# %% [markdown]
# ### Function

# %%
### X and y
def getXandY(Output_Vari):
    y_list = glob("01_Data/*_y_" + Output_Vari + "*.csv")
    y = pd.read_csv(y_list[0], index_col=0)
    y = y.iloc[:,0].to_numpy()
    X_list = glob("01_Data/*_X_" + Output_Vari + "*.csv")
    X = pd.read_csv(X_list[0], index_col=0)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, 
                                                        random_state=1)
    return X_train, X_test, y_train, y_test

# %% [markdown]
# ## Experiment for Happiness

# %% [markdown]
# ### Load Data

# %%
Output_Vari = "Happinessoverall"

# %%
X_train, X_test, y_train, y_test = getXandY(Output_Vari)

# %%
X_train.head()
# Out:
#         year        lat         lon  female  age  high_stress  low_stress  \
# 329671  2016  37.183964  138.256897       1   51            4           5
# 24633   2015  37.239090  140.353348       1   26            5           5
# 279845  2016  35.528252  140.185822       0   67            2           1
# 269295  2016  33.566044  130.342041       1   35            1           3
# 232515  2015  33.619823  130.515259       1   32            4           4
#
#         easy_to_relax  good_for_living  live_environment_satefy  ...  \
# 329671              3                4                        3  ...
# 24633               3                3                        4  ...
# 279845              4                4                        3  ...
# 269295              4                4                        3  ...
# 232515              2                4                        3  ...
#
#         housewife  retired  unemployed  college_no_diploma  bachelor  master  \
# 329671          0        0           0                   0         0       0
# 24633           0        0           0                   1         0       0
# 279845          0        0           0                   0         1       0
# 269295          1        0           0                   1         0       0
# 232515          1        0           0                   0         1       0
#
#         phd  income_indiv       NDVI        NTL
# 329671    0           3.5  29.553186   4.315041
# 24633     0           1.0  40.441441   2.005019
# 279845    0           1.0  53.940829   7.728996
# 269295    0           1.0  30.014896  17.481237
# 232515    0           2.5  55.156878   5.779940
#
# [5 rows x 29 columns]

# %%
X_train.describe()
# Out:
#                 year            lat            lon         female  \
# count  344855.000000  344855.000000  344855.000000  344855.000000
# mean     2015.656540      35.708914     137.514520       0.352612
# std         0.771443       2.131133       3.052344       0.477784
# min      2015.000000      24.301767     123.762947       0.000000
# 25%      2015.000000      34.747284     135.545242       0.000000
# 50%      2015.000000      35.477516     138.984985       0.000000
# 75%      2016.000000      35.809013     139.715393       1.000000
# max      2017.000000      45.511021     145.742340       1.000000
#
#                  age    high_stress     low_stress  easy_to_relax  \
# count  344855.000000  344855.000000  344855.000000  344855.000000
# mean       48.967114       3.172557       3.606846       3.293581
# std        11.731917       1.166244       1.060261       1.020122
# min        17.000000       1.000000       1.000000       1.000000
# 25%        41.000000       2.000000       3.000000       3.000000
# 50%        49.000000       3.000000       4.000000       4.000000
# 75%        57.000000       4.000000       4.000000       4.000000
# max       101.000000       5.000000       5.000000       5.000000
#
#        good_for_living  live_environment_satefy  ...      housewife  \
# count    344855.000000            344855.000000  ...  344855.000000
# mean          3.826623                 2.953085  ...       0.086381
# std           0.897251                 0.761716  ...       0.280927
# min           1.000000                 0.000000  ...       0.000000
# 25%           3.000000                 3.000000  ...       0.000000
# 50%           4.000000                 3.000000  ...       0.000000
# 75%           4.000000                 3.000000  ...       0.000000
# max           5.000000                 4.000000  ...       1.000000
#
#              retired     unemployed  college_no_diploma       bachelor  \
# count  344855.000000  344855.000000       344855.000000  344855.000000
# mean        0.064410       0.046147            0.209624       0.437245
# std         0.245482       0.209804            0.407041       0.496047
# min         0.000000       0.000000            0.000000       0.000000
# 25%         0.000000       0.000000            0.000000       0.000000
# 50%         0.000000       0.000000            0.000000       0.000000
# 75%         0.000000       0.000000            0.000000       1.000000
# max         1.000000       1.000000            1.000000       1.000000
#
#               master            phd   income_indiv           NDVI  \
# count  344855.000000  344855.000000  344855.000000  344855.000000
# mean        0.047295       0.013539       4.686452      36.247119
# std         0.212270       0.115567       3.903289      13.664925
# min         0.000000       0.000000       1.000000       4.860561
# 25%         0.000000       0.000000       1.000000      26.247235
# 50%         0.000000       0.000000       3.500000      34.654246
# 75%         0.000000       0.000000       6.500000      44.238307
# max         1.000000       1.000000      30.000000      87.709065
#
#                  NTL
# count  344855.000000
# mean       18.599653
# std        15.865111
# min         0.013894
# 25%         6.048134
# 50%        14.545732
# 75%        26.747059
# max        88.380999
#
# [8 rows x 29 columns]

# %%
X_train.columns
# Out:
# Index(['year', 'lat', 'lon', 'female', 'age', 'high_stress', 'low_stress',
#        'easy_to_relax', 'good_for_living', 'live_environment_satefy',
#        'community_attachment', 'income', 'self_reported_health', 'student',
#        'worker', 'company_owner', 'government_officer', 'self_employed',
#        'professional', 'housewife', 'retired', 'unemployed',
#        'college_no_diploma', 'bachelor', 'master', 'phd', 'income_indiv',
#        'NDVI', 'NTL'],
#       dtype='object')

# %%
X_train.shape
# Out:
# (344855, 29)

# %%
X_test.shape
# Out:
# (38318, 29)

# %%
X = pd.concat([X_train, X_test])

# %%
X.shape
# Out:
# (383173, 29)

# %%
y = np.concatenate([y_train, y_test])

# %%
y.shape
# Out:
# (383173,)

# %% [markdown]
# ### Run Test Model

# %%
rf_reg =RandomForestRegressor(n_bins=256)

# %%
param_grid = {
    "n_estimators": list(range(1_000, 5_100, 100)),
    "max_depth": [2, 4, 8, 16],
    "max_features": [0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
    "min_samples_split": [2, 4, 8, 16, 32],
    "max_samples": [0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1.0]
}

# %%
class RandomRunNFoldsKFold(KFold):
    def __init__(self, n_splits=10, random_state=None, run_splits=3, **kwargs):
        super().__init__(n_splits=n_splits, shuffle=True, random_state=random_state, **kwargs)
        self.random_state = random_state
        self.actual_splits = run_splits  # Number of actual splits to use

    def split(self, X, y=None, groups=None):
        folds = list(super().split(X, y, groups))
        if self.random_state is not None:
            random.seed(self.random_state)
        selected_folds = random.sample(folds, self.actual_splits)
        for train_index, test_index in selected_folds:
            yield train_index, test_index

    def get_n_splits(self, X=None, y=None, groups=None):
        return self.actual_splits

# %%
rkfcv = RandomRunNFoldsKFold(n_splits=10, run_splits=3, random_state=42)

# %%
random_search = RandomizedSearchCV(
    estimator=rf_reg,
    param_distributions=param_grid,
    n_iter=500,  # Number of parameter settings to sample
    scoring="r2",
    cv=rkfcv,  # 3-fold cross-validation
    random_state=42,
    verbose=2,
    return_train_score = False
)

# %%
# Fit the model
random_search.fit(X, y)
# Out:
# Fitting 3 folds for each of 500 candidates, totalling 1500 fits
# [CV] END max_depth=2, max_features=0.6, max_samples=0.8, min_samples_split=2, n_estimators=1800; total time=  26.3s
# [CV] END max_depth=2, max_features=0.6, max_samples=0.8, min_samples_split=2, n_estimators=1800; total time=  26.1s
# [CV] END max_depth=2, max_features=0.6, max_samples=0.8, min_samples_split=2, n_estimators=1800; total time=  25.9s
# [CV] END max_depth=2, max_features=0.5, max_samples=0.5, min_samples_split=32, n_estimators=1400; total time=  14.9s
# [CV] END max_depth=2, max_features=0.5, max_samples=0.5, min_samples_split=32, n_estimators=1400; total time=  14.9s
# [CV] END max_depth=2, max_features=0.5, max_samples=0.5, min_samples_split=32, n_estimators=1400; total time=  15.2s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.6, min_samples_split=32, n_estimators=2100; total time=  24.3s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.6, min_samples_split=32, n_estimators=2100; total time=  24.8s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.6, min_samples_split=32, n_estimators=2100; total time=  24.6s
# [CV] END max_depth=2, max_features=1.0, max_samples=0.5, min_samples_split=32, n_estimators=3900; total time=  42.0s
# [CV] END max_depth=2, max_features=1.0, max_samples=0.5, min_samples_split=32, n_estimators=3900; total time=  42.5s
# [CV] END max_depth=2, max_features=1.0, max_samples=0.5, min_samples_split=32, n_estimators=3900; total time=  43.0s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.8, min_samples_split=2, n_estimators=3200; total time=  45.0s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.8, min_samples_split=2, n_estimators=3200; total time=  44.3s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.8, min_samples_split=2, n_estimators=3200; total time=  44.8s
# [CV] END max_depth=2, max_features=0.7, max_samples=0.8, min_samples_split=8, n_estimators=3400; total time=  49.1s
# [CV] END max_depth=2, max_features=0.7, max_samples=0.8, min_samples_split=8, n_estimators=3400; total time=  49.6s
# [CV] END max_depth=2, max_features=0.7, max_samples=0.8, min_samples_split=8, n_estimators=3400; total time=  48.8s
# [CV] END max_depth=2, max_features=0.6, max_samples=0.8, min_samples_split=32, n_estimators=3200; total time=  45.5s
# [CV] END max_depth=2, max_features=0.6, max_samples=0.8, min_samples_split=32, n_estimators=3200; total time=  46.2s
# [CV] END max_depth=2, max_features=0.6, max_samples=0.8, min_samples_split=32, n_estimators=3200; total time=  46.0s
# [CV] END max_depth=2, max_features=0.8, max_samples=0.5, min_samples_split=2, n_estimators=1900; total time=  20.5s
# [CV] END max_depth=2, max_features=0.8, max_samples=0.5, min_samples_split=2, n_estimators=1900; total time=  20.3s
# [CV] END max_depth=2, max_features=0.8, max_samples=0.5, min_samples_split=2, n_estimators=1900; total time=  20.5s
# [CV] END max_depth=8, max_features=0.8, max_samples=0.5, min_samples_split=2, n_estimators=1800; total time=  22.1s
# [CV] END max_depth=8, max_features=0.8, max_samples=0.5, min_samples_split=2, n_estimators=1800; total time=  22.2s
# [CV] END max_depth=8, max_features=0.8, max_samples=0.5, min_samples_split=2, n_estimators=1800; total time=  22.1s
# [CV] END max_depth=16, max_features=0.4, max_samples=0.5, min_samples_split=16, n_estimators=3800; total time=  58.4s
# [CV] END max_depth=16, max_features=0.4, max_samples=0.5, min_samples_split=16, n_estimators=3800; total time=  59.0s
# [CV] END max_depth=16, max_features=0.4, max_samples=0.5, min_samples_split=16, n_estimators=3800; total time=  59.0s
# [CV] END max_depth=4, max_features=0.9, max_samples=0.6, min_samples_split=4, n_estimators=1800; total time=  21.2s
# [CV] END max_depth=4, max_features=0.9, max_samples=0.6, min_samples_split=4, n_estimators=1800; total time=  21.1s
# [CV] END max_depth=4, max_features=0.9, max_samples=0.6, min_samples_split=4, n_estimators=1800; total time=  21.2s
# [CV] END max_depth=2, max_features=0.8, max_samples=0.9, min_samples_split=4, n_estimators=3600; total time=  56.1s
# [CV] END max_depth=2, max_features=0.8, max_samples=0.9, min_samples_split=4, n_estimators=3600; total time=  55.6s
# [CV] END max_depth=2, max_features=0.8, max_samples=0.9, min_samples_split=4, n_estimators=3600; total time=  55.8s
# [CV] END max_depth=2, max_features=1.0, max_samples=0.8, min_samples_split=16, n_estimators=1300; total time=  18.9s
# [CV] END max_depth=2, max_features=1.0, max_samples=0.8, min_samples_split=16, n_estimators=1300; total time=  19.2s
# [CV] END max_depth=2, max_features=1.0, max_samples=0.8, min_samples_split=16, n_estimators=1300; total time=  19.0s
# [CV] END max_depth=4, max_features=0.9, max_samples=0.7, min_samples_split=4, n_estimators=1100; total time=  13.3s
# [CV] END max_depth=4, max_features=0.9, max_samples=0.7, min_samples_split=4, n_estimators=1100; total time=  13.6s
# [CV] END max_depth=4, max_features=0.9, max_samples=0.7, min_samples_split=4, n_estimators=1100; total time=  13.9s
# [CV] END max_depth=16, max_features=0.9, max_samples=0.4, min_samples_split=16, n_estimators=1100; total time=  19.0s
# [CV] END max_depth=16, max_features=0.9, max_samples=0.4, min_samples_split=16, n_estimators=1100; total time=  18.9s
# [CV] END max_depth=16, max_features=0.9, max_samples=0.4, min_samples_split=16, n_estimators=1100; total time=  18.9s
# [CV] END max_depth=4, max_features=0.9, max_samples=0.4, min_samples_split=4, n_estimators=3000; total time=  29.0s
# [CV] END max_depth=4, max_features=0.9, max_samples=0.4, min_samples_split=4, n_estimators=3000; total time=  29.4s
# [CV] END max_depth=4, max_features=0.9, max_samples=0.4, min_samples_split=4, n_estimators=3000; total time=  29.8s
# [CV] END max_depth=16, max_features=0.6, max_samples=0.7, min_samples_split=16, n_estimators=4800; total time= 1.6min
# [CV] END max_depth=16, max_features=0.6, max_samples=0.7, min_samples_split=16, n_estimators=4800; total time= 1.6min
# [CV] END max_depth=16, max_features=0.6, max_samples=0.7, min_samples_split=16, n_estimators=4800; total time= 1.7min
# [CV] END max_depth=4, max_features=0.5, max_samples=0.8, min_samples_split=2, n_estimators=3700; total time=  48.4s
# [CV] END max_depth=4, max_features=0.5, max_samples=0.8, min_samples_split=2, n_estimators=3700; total time=  48.4s
# [CV] END max_depth=4, max_features=0.5, max_samples=0.8, min_samples_split=2, n_estimators=3700; total time=  47.9s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.7, min_samples_split=2, n_estimators=1400; total time=  22.4s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.7, min_samples_split=2, n_estimators=1400; total time=  22.7s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.7, min_samples_split=2, n_estimators=1400; total time=  22.6s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.4, min_samples_split=32, n_estimators=1400; total time=  16.5s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.4, min_samples_split=32, n_estimators=1400; total time=  16.6s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.4, min_samples_split=32, n_estimators=1400; total time=  16.5s
# [CV] END max_depth=16, max_features=0.5, max_samples=1.0, min_samples_split=16, n_estimators=2200; total time=  51.9s
# [CV] END max_depth=16, max_features=0.5, max_samples=1.0, min_samples_split=16, n_estimators=2200; total time=  52.0s
# [CV] END max_depth=16, max_features=0.5, max_samples=1.0, min_samples_split=16, n_estimators=2200; total time=  51.6s
# [CV] END max_depth=2, max_features=1.0, max_samples=0.6, min_samples_split=8, n_estimators=3600; total time=  43.1s
# [CV] END max_depth=2, max_features=1.0, max_samples=0.6, min_samples_split=8, n_estimators=3600; total time=  43.2s
# [CV] END max_depth=2, max_features=1.0, max_samples=0.6, min_samples_split=8, n_estimators=3600; total time=  43.2s
# [CV] END max_depth=8, max_features=1.0, max_samples=1.0, min_samples_split=32, n_estimators=1000; total time=  20.2s
# [CV] END max_depth=8, max_features=1.0, max_samples=1.0, min_samples_split=32, n_estimators=1000; total time=  20.4s
# [CV] END max_depth=8, max_features=1.0, max_samples=1.0, min_samples_split=32, n_estimators=1000; total time=  20.2s
# [CV] END max_depth=4, max_features=0.9, max_samples=0.9, min_samples_split=8, n_estimators=4100; total time= 1.0min
# [CV] END max_depth=4, max_features=0.9, max_samples=0.9, min_samples_split=8, n_estimators=4100; total time= 1.0min
# [CV] END max_depth=4, max_features=0.9, max_samples=0.9, min_samples_split=8, n_estimators=4100; total time= 1.0min
# [CV] END max_depth=16, max_features=1.0, max_samples=1.0, min_samples_split=8, n_estimators=5000; total time= 2.8min
# [CV] END max_depth=16, max_features=1.0, max_samples=1.0, min_samples_split=8, n_estimators=5000; total time= 2.8min
# [CV] END max_depth=16, max_features=1.0, max_samples=1.0, min_samples_split=8, n_estimators=5000; total time= 2.8min
# [CV] END max_depth=8, max_features=0.9, max_samples=0.9, min_samples_split=8, n_estimators=4000; total time= 1.2min
# [CV] END max_depth=8, max_features=0.9, max_samples=0.9, min_samples_split=8, n_estimators=4000; total time= 1.2min
# [CV] END max_depth=8, max_features=0.9, max_samples=0.9, min_samples_split=8, n_estimators=4000; total time= 1.2min
# [CV] END max_depth=16, max_features=0.5, max_samples=0.9, min_samples_split=16, n_estimators=4800; total time= 1.8min
# [CV] END max_depth=16, max_features=0.5, max_samples=0.9, min_samples_split=16, n_estimators=4800; total time= 1.9min
# [CV] END max_depth=16, max_features=0.5, max_samples=0.9, min_samples_split=16, n_estimators=4800; total time= 1.9min
# [CV] END max_depth=2, max_features=0.6, max_samples=0.4, min_samples_split=16, n_estimators=3500; total time=  33.1s
# [CV] END max_depth=2, max_features=0.6, max_samples=0.4, min_samples_split=16, n_estimators=3500; total time=  32.6s
# [CV] END max_depth=2, max_features=0.6, max_samples=0.4, min_samples_split=16, n_estimators=3500; total time=  32.7s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.4, min_samples_split=8, n_estimators=1700; total time=  16.4s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.4, min_samples_split=8, n_estimators=1700; total time=  16.6s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.4, min_samples_split=8, n_estimators=1700; total time=  16.5s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.4, min_samples_split=16, n_estimators=2700; total time=  26.5s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.4, min_samples_split=16, n_estimators=2700; total time=  26.4s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.4, min_samples_split=16, n_estimators=2700; total time=  26.6s
# [CV] END max_depth=4, max_features=0.5, max_samples=0.6, min_samples_split=16, n_estimators=2700; total time=  29.9s
# [CV] END max_depth=4, max_features=0.5, max_samples=0.6, min_samples_split=16, n_estimators=2700; total time=  30.0s
# [CV] END max_depth=4, max_features=0.5, max_samples=0.6, min_samples_split=16, n_estimators=2700; total time=  30.0s
# [CV] END max_depth=4, max_features=0.6, max_samples=0.9, min_samples_split=4, n_estimators=4900; total time= 1.1min
# [CV] END max_depth=4, max_features=0.6, max_samples=0.9, min_samples_split=4, n_estimators=4900; total time= 1.1min
# [CV] END max_depth=4, max_features=0.6, max_samples=0.9, min_samples_split=4, n_estimators=4900; total time= 1.1min
# [CV] END max_depth=8, max_features=1.0, max_samples=0.8, min_samples_split=16, n_estimators=1000; total time=  17.6s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.8, min_samples_split=16, n_estimators=1000; total time=  17.5s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.8, min_samples_split=16, n_estimators=1000; total time=  17.6s
# [CV] END max_depth=16, max_features=0.4, max_samples=0.9, min_samples_split=8, n_estimators=1800; total time=  37.4s
# [CV] END max_depth=16, max_features=0.4, max_samples=0.9, min_samples_split=8, n_estimators=1800; total time=  37.4s
# [CV] END max_depth=16, max_features=0.4, max_samples=0.9, min_samples_split=8, n_estimators=1800; total time=  37.5s
# [CV] END max_depth=16, max_features=0.5, max_samples=0.6, min_samples_split=2, n_estimators=2400; total time=  45.1s
# [CV] END max_depth=16, max_features=0.5, max_samples=0.6, min_samples_split=2, n_estimators=2400; total time=  45.5s
# [CV] END max_depth=16, max_features=0.5, max_samples=0.6, min_samples_split=2, n_estimators=2400; total time=  45.2s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.9, min_samples_split=2, n_estimators=1600; total time=  24.1s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.9, min_samples_split=2, n_estimators=1600; total time=  24.2s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.9, min_samples_split=2, n_estimators=1600; total time=  24.3s
# [CV] END max_depth=4, max_features=0.6, max_samples=0.6, min_samples_split=16, n_estimators=3300; total time=  37.2s
# [CV] END max_depth=4, max_features=0.6, max_samples=0.6, min_samples_split=16, n_estimators=3300; total time=  37.4s
# [CV] END max_depth=4, max_features=0.6, max_samples=0.6, min_samples_split=16, n_estimators=3300; total time=  37.3s
# [CV] END max_depth=8, max_features=0.9, max_samples=0.7, min_samples_split=4, n_estimators=3600; total time=  55.5s
# [CV] END max_depth=8, max_features=0.9, max_samples=0.7, min_samples_split=4, n_estimators=3600; total time=  55.9s
# [CV] END max_depth=8, max_features=0.9, max_samples=0.7, min_samples_split=4, n_estimators=3600; total time=  55.4s
# [CV] END max_depth=16, max_features=0.5, max_samples=0.9, min_samples_split=8, n_estimators=1200; total time=  27.2s
# [CV] END max_depth=16, max_features=0.5, max_samples=0.9, min_samples_split=8, n_estimators=1200; total time=  27.2s
# [CV] END max_depth=16, max_features=0.5, max_samples=0.9, min_samples_split=8, n_estimators=1200; total time=  27.3s
# [CV] END max_depth=4, max_features=0.8, max_samples=0.8, min_samples_split=16, n_estimators=4600; total time= 1.0min
# [CV] END max_depth=4, max_features=0.8, max_samples=0.8, min_samples_split=16, n_estimators=4600; total time= 1.0min
# [CV] END max_depth=4, max_features=0.8, max_samples=0.8, min_samples_split=16, n_estimators=4600; total time= 1.0min
# [CV] END max_depth=2, max_features=0.9, max_samples=0.8, min_samples_split=16, n_estimators=4500; total time= 1.1min
# [CV] END max_depth=2, max_features=0.9, max_samples=0.8, min_samples_split=16, n_estimators=4500; total time= 1.1min
# [CV] END max_depth=2, max_features=0.9, max_samples=0.8, min_samples_split=16, n_estimators=4500; total time= 1.1min
# [CV] END max_depth=16, max_features=1.0, max_samples=0.4, min_samples_split=16, n_estimators=4200; total time= 1.2min
# [CV] END max_depth=16, max_features=1.0, max_samples=0.4, min_samples_split=16, n_estimators=4200; total time= 1.3min
# [CV] END max_depth=16, max_features=1.0, max_samples=0.4, min_samples_split=16, n_estimators=4200; total time= 1.3min
# [CV] END max_depth=2, max_features=0.9, max_samples=0.5, min_samples_split=32, n_estimators=2900; total time=  31.3s
# [CV] END max_depth=2, max_features=0.9, max_samples=0.5, min_samples_split=32, n_estimators=2900; total time=  31.2s
# [CV] END max_depth=2, max_features=0.9, max_samples=0.5, min_samples_split=32, n_estimators=2900; total time=  31.0s
# [CV] END max_depth=16, max_features=0.7, max_samples=0.5, min_samples_split=8, n_estimators=1400; total time=  25.4s
# [CV] END max_depth=16, max_features=0.7, max_samples=0.5, min_samples_split=8, n_estimators=1400; total time=  25.5s
# [CV] END max_depth=16, max_features=0.7, max_samples=0.5, min_samples_split=8, n_estimators=1400; total time=  25.5s
# [CV] END max_depth=2, max_features=0.5, max_samples=0.4, min_samples_split=2, n_estimators=3900; total time=  36.6s
# [CV] END max_depth=2, max_features=0.5, max_samples=0.4, min_samples_split=2, n_estimators=3900; total time=  36.8s
# [CV] END max_depth=2, max_features=0.5, max_samples=0.4, min_samples_split=2, n_estimators=3900; total time=  36.2s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.8, min_samples_split=16, n_estimators=1000; total time=  13.7s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.8, min_samples_split=16, n_estimators=1000; total time=  13.9s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.8, min_samples_split=16, n_estimators=1000; total time=  13.9s
# [CV] END max_depth=16, max_features=1.0, max_samples=0.9, min_samples_split=16, n_estimators=3900; total time= 1.9min
# [CV] END max_depth=16, max_features=1.0, max_samples=0.9, min_samples_split=16, n_estimators=3900; total time= 2.0min
# [CV] END max_depth=16, max_features=1.0, max_samples=0.9, min_samples_split=16, n_estimators=3900; total time= 2.0min
# [CV] END max_depth=16, max_features=0.9, max_samples=0.8, min_samples_split=4, n_estimators=1600; total time=  44.7s
# [CV] END max_depth=16, max_features=0.9, max_samples=0.8, min_samples_split=4, n_estimators=1600; total time=  45.0s
# [CV] END max_depth=16, max_features=0.9, max_samples=0.8, min_samples_split=4, n_estimators=1600; total time=  45.1s
# [CV] END max_depth=8, max_features=0.9, max_samples=1.0, min_samples_split=4, n_estimators=5000; total time= 1.6min
# [CV] END max_depth=8, max_features=0.9, max_samples=1.0, min_samples_split=4, n_estimators=5000; total time= 1.6min
# [CV] END max_depth=8, max_features=0.9, max_samples=1.0, min_samples_split=4, n_estimators=5000; total time= 1.6min
# [CV] END max_depth=4, max_features=0.6, max_samples=1.0, min_samples_split=8, n_estimators=1200; total time=  18.0s
# [CV] END max_depth=4, max_features=0.6, max_samples=1.0, min_samples_split=8, n_estimators=1200; total time=  17.8s
# [CV] END max_depth=4, max_features=0.6, max_samples=1.0, min_samples_split=8, n_estimators=1200; total time=  18.1s
# [CV] END max_depth=16, max_features=0.4, max_samples=0.5, min_samples_split=8, n_estimators=3900; total time=  59.0s
# [CV] END max_depth=16, max_features=0.4, max_samples=0.5, min_samples_split=8, n_estimators=3900; total time=  59.0s
# [CV] END max_depth=16, max_features=0.4, max_samples=0.5, min_samples_split=8, n_estimators=3900; total time=  58.8s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.4, min_samples_split=16, n_estimators=1300; total time=  12.7s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.4, min_samples_split=16, n_estimators=1300; total time=  12.6s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.4, min_samples_split=16, n_estimators=1300; total time=  12.6s
# [CV] END max_depth=4, max_features=0.5, max_samples=0.7, min_samples_split=4, n_estimators=1400; total time=  16.7s
# [CV] END max_depth=4, max_features=0.5, max_samples=0.7, min_samples_split=4, n_estimators=1400; total time=  16.7s
# [CV] END max_depth=4, max_features=0.5, max_samples=0.7, min_samples_split=4, n_estimators=1400; total time=  16.7s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.4, min_samples_split=32, n_estimators=3300; total time=  32.3s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.4, min_samples_split=32, n_estimators=3300; total time=  32.4s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.4, min_samples_split=32, n_estimators=3300; total time=  32.0s
# [CV] END max_depth=8, max_features=0.7, max_samples=0.7, min_samples_split=2, n_estimators=1500; total time=  21.3s
# [CV] END max_depth=8, max_features=0.7, max_samples=0.7, min_samples_split=2, n_estimators=1500; total time=  21.4s
# [CV] END max_depth=8, max_features=0.7, max_samples=0.7, min_samples_split=2, n_estimators=1500; total time=  21.3s
# [CV] END max_depth=8, max_features=0.6, max_samples=0.6, min_samples_split=32, n_estimators=3800; total time=  47.1s
# [CV] END max_depth=8, max_features=0.6, max_samples=0.6, min_samples_split=32, n_estimators=3800; total time=  47.3s
# [CV] END max_depth=8, max_features=0.6, max_samples=0.6, min_samples_split=32, n_estimators=3800; total time=  47.4s
# [CV] END max_depth=2, max_features=0.6, max_samples=0.9, min_samples_split=16, n_estimators=4800; total time= 1.2min
# [CV] END max_depth=2, max_features=0.6, max_samples=0.9, min_samples_split=16, n_estimators=4800; total time= 1.2min
# [CV] END max_depth=2, max_features=0.6, max_samples=0.9, min_samples_split=16, n_estimators=4800; total time= 1.2min
# [CV] END max_depth=4, max_features=0.5, max_samples=0.4, min_samples_split=4, n_estimators=2100; total time=  18.2s
# [CV] END max_depth=4, max_features=0.5, max_samples=0.4, min_samples_split=4, n_estimators=2100; total time=  19.4s
# [CV] END max_depth=4, max_features=0.5, max_samples=0.4, min_samples_split=4, n_estimators=2100; total time=  19.5s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.8, min_samples_split=16, n_estimators=4600; total time=  57.4s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.8, min_samples_split=16, n_estimators=4600; total time=  57.6s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.8, min_samples_split=16, n_estimators=4600; total time=  57.2s
# [CV] END max_depth=4, max_features=0.6, max_samples=0.9, min_samples_split=16, n_estimators=4600; total time= 1.1min
# [CV] END max_depth=4, max_features=0.6, max_samples=0.9, min_samples_split=16, n_estimators=4600; total time= 1.1min
# [CV] END max_depth=4, max_features=0.6, max_samples=0.9, min_samples_split=16, n_estimators=4600; total time= 1.1min
# [CV] END max_depth=8, max_features=0.8, max_samples=0.6, min_samples_split=8, n_estimators=4900; total time= 1.1min
# [CV] END max_depth=8, max_features=0.8, max_samples=0.6, min_samples_split=8, n_estimators=4900; total time= 1.1min
# [CV] END max_depth=8, max_features=0.8, max_samples=0.6, min_samples_split=8, n_estimators=4900; total time= 1.1min
# [CV] END max_depth=8, max_features=0.7, max_samples=1.0, min_samples_split=8, n_estimators=3500; total time= 1.0min
# [CV] END max_depth=8, max_features=0.7, max_samples=1.0, min_samples_split=8, n_estimators=3500; total time= 1.0min
# [CV] END max_depth=8, max_features=0.7, max_samples=1.0, min_samples_split=8, n_estimators=3500; total time= 1.0min
# [CV] END max_depth=8, max_features=1.0, max_samples=0.6, min_samples_split=32, n_estimators=4600; total time= 1.1min
# [CV] END max_depth=8, max_features=1.0, max_samples=0.6, min_samples_split=32, n_estimators=4600; total time= 1.1min
# [CV] END max_depth=8, max_features=1.0, max_samples=0.6, min_samples_split=32, n_estimators=4600; total time= 1.1min
# [CV] END max_depth=8, max_features=0.9, max_samples=0.4, min_samples_split=2, n_estimators=2900; total time=  33.1s
# [CV] END max_depth=8, max_features=0.9, max_samples=0.4, min_samples_split=2, n_estimators=2900; total time=  33.2s
# [CV] END max_depth=8, max_features=0.9, max_samples=0.4, min_samples_split=2, n_estimators=2900; total time=  32.9s
# [CV] END max_depth=2, max_features=0.8, max_samples=0.4, min_samples_split=4, n_estimators=2400; total time=  23.0s
# [CV] END max_depth=2, max_features=0.8, max_samples=0.4, min_samples_split=4, n_estimators=2400; total time=  23.0s
# [CV] END max_depth=2, max_features=0.8, max_samples=0.4, min_samples_split=4, n_estimators=2400; total time=  23.0s
# [CV] END max_depth=2, max_features=0.5, max_samples=0.7, min_samples_split=8, n_estimators=3600; total time=  47.1s
# [CV] END max_depth=2, max_features=0.5, max_samples=0.7, min_samples_split=8, n_estimators=3600; total time=  47.0s
# [CV] END max_depth=2, max_features=0.5, max_samples=0.7, min_samples_split=8, n_estimators=3600; total time=  46.7s
# [CV] END max_depth=16, max_features=0.9, max_samples=0.4, min_samples_split=2, n_estimators=2100; total time=  39.9s
# [CV] END max_depth=16, max_features=0.9, max_samples=0.4, min_samples_split=2, n_estimators=2100; total time=  40.4s
# [CV] END max_depth=16, max_features=0.9, max_samples=0.4, min_samples_split=2, n_estimators=2100; total time=  40.6s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.4, min_samples_split=8, n_estimators=3500; total time=  32.1s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.4, min_samples_split=8, n_estimators=3500; total time=  32.0s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.4, min_samples_split=8, n_estimators=3500; total time=  32.0s
# [CV] END max_depth=16, max_features=0.7, max_samples=0.8, min_samples_split=4, n_estimators=4400; total time= 1.8min
# [CV] END max_depth=16, max_features=0.7, max_samples=0.8, min_samples_split=4, n_estimators=4400; total time= 1.8min
# [CV] END max_depth=16, max_features=0.7, max_samples=0.8, min_samples_split=4, n_estimators=4400; total time= 1.8min
# [CV] END max_depth=4, max_features=0.8, max_samples=0.9, min_samples_split=8, n_estimators=1800; total time=  26.3s
# [CV] END max_depth=4, max_features=0.8, max_samples=0.9, min_samples_split=8, n_estimators=1800; total time=  26.3s
# [CV] END max_depth=4, max_features=0.8, max_samples=0.9, min_samples_split=8, n_estimators=1800; total time=  26.3s
# [CV] END max_depth=2, max_features=1.0, max_samples=1.0, min_samples_split=8, n_estimators=2400; total time=  41.6s
# [CV] END max_depth=2, max_features=1.0, max_samples=1.0, min_samples_split=8, n_estimators=2400; total time=  41.8s
# [CV] END max_depth=2, max_features=1.0, max_samples=1.0, min_samples_split=8, n_estimators=2400; total time=  41.2s
# [CV] END max_depth=16, max_features=0.9, max_samples=0.6, min_samples_split=4, n_estimators=4800; total time= 1.8min
# [CV] END max_depth=16, max_features=0.9, max_samples=0.6, min_samples_split=4, n_estimators=4800; total time= 1.9min
# [CV] END max_depth=16, max_features=0.9, max_samples=0.6, min_samples_split=4, n_estimators=4800; total time= 1.9min
# [CV] END max_depth=16, max_features=0.7, max_samples=0.8, min_samples_split=32, n_estimators=3200; total time= 1.2min
# [CV] END max_depth=16, max_features=0.7, max_samples=0.8, min_samples_split=32, n_estimators=3200; total time= 1.2min
# [CV] END max_depth=16, max_features=0.7, max_samples=0.8, min_samples_split=32, n_estimators=3200; total time= 1.2min
# [CV] END max_depth=4, max_features=1.0, max_samples=0.5, min_samples_split=16, n_estimators=2900; total time=  31.3s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.5, min_samples_split=16, n_estimators=2900; total time=  31.5s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.5, min_samples_split=16, n_estimators=2900; total time=  31.6s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.4, min_samples_split=32, n_estimators=2200; total time=  20.6s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.4, min_samples_split=32, n_estimators=2200; total time=  20.4s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.4, min_samples_split=32, n_estimators=2200; total time=  20.3s
# [CV] END max_depth=2, max_features=0.5, max_samples=0.4, min_samples_split=2, n_estimators=2600; total time=  24.6s
# [CV] END max_depth=2, max_features=0.5, max_samples=0.4, min_samples_split=2, n_estimators=2600; total time=  24.8s
# [CV] END max_depth=2, max_features=0.5, max_samples=0.4, min_samples_split=2, n_estimators=2600; total time=  24.7s
# [CV] END max_depth=2, max_features=0.5, max_samples=0.6, min_samples_split=2, n_estimators=3100; total time=  36.8s
# [CV] END max_depth=2, max_features=0.5, max_samples=0.6, min_samples_split=2, n_estimators=3100; total time=  36.8s
# [CV] END max_depth=2, max_features=0.5, max_samples=0.6, min_samples_split=2, n_estimators=3100; total time=  36.7s
# [CV] END max_depth=4, max_features=0.6, max_samples=0.8, min_samples_split=4, n_estimators=3100; total time=  39.9s
# [CV] END max_depth=4, max_features=0.6, max_samples=0.8, min_samples_split=4, n_estimators=3100; total time=  40.6s
# [CV] END max_depth=4, max_features=0.6, max_samples=0.8, min_samples_split=4, n_estimators=3100; total time=  40.5s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.4, min_samples_split=2, n_estimators=1700; total time=  16.6s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.4, min_samples_split=2, n_estimators=1700; total time=  16.8s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.4, min_samples_split=2, n_estimators=1700; total time=  16.7s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.5, min_samples_split=16, n_estimators=3400; total time=  33.9s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.5, min_samples_split=16, n_estimators=3400; total time=  34.3s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.5, min_samples_split=16, n_estimators=3400; total time=  33.9s
# [CV] END max_depth=16, max_features=1.0, max_samples=0.6, min_samples_split=4, n_estimators=1400; total time=  34.3s
# [CV] END max_depth=16, max_features=1.0, max_samples=0.6, min_samples_split=4, n_estimators=1400; total time=  34.3s
# [CV] END max_depth=16, max_features=1.0, max_samples=0.6, min_samples_split=4, n_estimators=1400; total time=  34.4s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.9, min_samples_split=32, n_estimators=1400; total time=  18.9s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.9, min_samples_split=32, n_estimators=1400; total time=  19.0s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.9, min_samples_split=32, n_estimators=1400; total time=  19.1s
# [CV] END max_depth=8, max_features=0.9, max_samples=0.5, min_samples_split=16, n_estimators=3000; total time=  38.2s
# [CV] END max_depth=8, max_features=0.9, max_samples=0.5, min_samples_split=16, n_estimators=3000; total time=  38.2s
# [CV] END max_depth=8, max_features=0.9, max_samples=0.5, min_samples_split=16, n_estimators=3000; total time=  38.1s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.4, min_samples_split=8, n_estimators=3900; total time=  45.9s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.4, min_samples_split=8, n_estimators=3900; total time=  46.1s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.4, min_samples_split=8, n_estimators=3900; total time=  46.1s
# [CV] END max_depth=16, max_features=0.6, max_samples=0.8, min_samples_split=16, n_estimators=3500; total time= 1.3min
# [CV] END max_depth=16, max_features=0.6, max_samples=0.8, min_samples_split=16, n_estimators=3500; total time= 1.3min
# [CV] END max_depth=16, max_features=0.6, max_samples=0.8, min_samples_split=16, n_estimators=3500; total time= 1.3min
# [CV] END max_depth=4, max_features=0.7, max_samples=0.9, min_samples_split=2, n_estimators=3200; total time=  46.2s
# [CV] END max_depth=4, max_features=0.7, max_samples=0.9, min_samples_split=2, n_estimators=3200; total time=  46.4s
# [CV] END max_depth=4, max_features=0.7, max_samples=0.9, min_samples_split=2, n_estimators=3200; total time=  46.3s
# [CV] END max_depth=2, max_features=0.5, max_samples=0.9, min_samples_split=32, n_estimators=3000; total time=  47.0s
# [CV] END max_depth=2, max_features=0.5, max_samples=0.9, min_samples_split=32, n_estimators=3000; total time=  46.6s
# [CV] END max_depth=2, max_features=0.5, max_samples=0.9, min_samples_split=32, n_estimators=3000; total time=  47.1s
# [CV] END max_depth=8, max_features=0.6, max_samples=1.0, min_samples_split=4, n_estimators=4000; total time= 1.1min
# [CV] END max_depth=8, max_features=0.6, max_samples=1.0, min_samples_split=4, n_estimators=4000; total time= 1.1min
# [CV] END max_depth=8, max_features=0.6, max_samples=1.0, min_samples_split=4, n_estimators=4000; total time= 1.1min
# [CV] END max_depth=2, max_features=0.9, max_samples=0.4, min_samples_split=32, n_estimators=4600; total time=  44.4s
# [CV] END max_depth=2, max_features=0.9, max_samples=0.4, min_samples_split=32, n_estimators=4600; total time=  44.2s
# [CV] END max_depth=2, max_features=0.9, max_samples=0.4, min_samples_split=32, n_estimators=4600; total time=  44.2s
# [CV] END max_depth=8, max_features=0.9, max_samples=0.5, min_samples_split=16, n_estimators=1700; total time=  21.7s
# [CV] END max_depth=8, max_features=0.9, max_samples=0.5, min_samples_split=16, n_estimators=1700; total time=  21.7s
# [CV] END max_depth=8, max_features=0.9, max_samples=0.5, min_samples_split=16, n_estimators=1700; total time=  21.7s
# [CV] END max_depth=2, max_features=1.0, max_samples=0.4, min_samples_split=8, n_estimators=4100; total time=  39.1s
# [CV] END max_depth=2, max_features=1.0, max_samples=0.4, min_samples_split=8, n_estimators=4100; total time=  39.8s
# [CV] END max_depth=2, max_features=1.0, max_samples=0.4, min_samples_split=8, n_estimators=4100; total time=  39.7s
# [CV] END max_depth=8, max_features=0.5, max_samples=0.5, min_samples_split=8, n_estimators=3500; total time=  38.7s
# [CV] END max_depth=8, max_features=0.5, max_samples=0.5, min_samples_split=8, n_estimators=3500; total time=  38.8s
# [CV] END max_depth=8, max_features=0.5, max_samples=0.5, min_samples_split=8, n_estimators=3500; total time=  38.8s
# [CV] END max_depth=2, max_features=0.9, max_samples=0.8, min_samples_split=32, n_estimators=2100; total time=  30.6s
# [CV] END max_depth=2, max_features=0.9, max_samples=0.8, min_samples_split=32, n_estimators=2100; total time=  30.5s
# [CV] END max_depth=2, max_features=0.9, max_samples=0.8, min_samples_split=32, n_estimators=2100; total time=  30.5s
# [CV] END max_depth=2, max_features=0.6, max_samples=0.7, min_samples_split=2, n_estimators=1300; total time=  17.1s
# [CV] END max_depth=2, max_features=0.6, max_samples=0.7, min_samples_split=2, n_estimators=1300; total time=  17.2s
# [CV] END max_depth=2, max_features=0.6, max_samples=0.7, min_samples_split=2, n_estimators=1300; total time=  17.0s
# [CV] END max_depth=2, max_features=1.0, max_samples=1.0, min_samples_split=8, n_estimators=4800; total time= 1.4min
# [CV] END max_depth=2, max_features=1.0, max_samples=1.0, min_samples_split=8, n_estimators=4800; total time= 1.4min
# [CV] END max_depth=2, max_features=1.0, max_samples=1.0, min_samples_split=8, n_estimators=4800; total time= 1.4min
# [CV] END max_depth=2, max_features=0.5, max_samples=0.5, min_samples_split=8, n_estimators=1900; total time=  20.1s
# [CV] END max_depth=2, max_features=0.5, max_samples=0.5, min_samples_split=8, n_estimators=1900; total time=  19.9s
# [CV] END max_depth=2, max_features=0.5, max_samples=0.5, min_samples_split=8, n_estimators=1900; total time=  20.4s
# [CV] END max_depth=16, max_features=0.6, max_samples=1.0, min_samples_split=8, n_estimators=4100; total time= 1.8min
# [CV] END max_depth=16, max_features=0.6, max_samples=1.0, min_samples_split=8, n_estimators=4100; total time= 1.8min
# [CV] END max_depth=16, max_features=0.6, max_samples=1.0, min_samples_split=8, n_estimators=4100; total time= 1.8min
# [CV] END max_depth=8, max_features=0.4, max_samples=0.7, min_samples_split=8, n_estimators=4400; total time=  55.2s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.7, min_samples_split=8, n_estimators=4400; total time=  55.2s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.7, min_samples_split=8, n_estimators=4400; total time=  55.1s
# [CV] END max_depth=4, max_features=0.5, max_samples=0.8, min_samples_split=4, n_estimators=3000; total time=  38.9s
# [CV] END max_depth=4, max_features=0.5, max_samples=0.8, min_samples_split=4, n_estimators=3000; total time=  38.8s
# [CV] END max_depth=4, max_features=0.5, max_samples=0.8, min_samples_split=4, n_estimators=3000; total time=  38.8s
# [CV] END max_depth=8, max_features=0.5, max_samples=0.8, min_samples_split=2, n_estimators=1300; total time=  18.4s
# [CV] END max_depth=8, max_features=0.5, max_samples=0.8, min_samples_split=2, n_estimators=1300; total time=  18.3s
# [CV] END max_depth=8, max_features=0.5, max_samples=0.8, min_samples_split=2, n_estimators=1300; total time=  18.5s
# [CV] END max_depth=4, max_features=0.9, max_samples=0.9, min_samples_split=16, n_estimators=4000; total time=  59.4s
# [CV] END max_depth=4, max_features=0.9, max_samples=0.9, min_samples_split=16, n_estimators=4000; total time=  58.9s
# [CV] END max_depth=4, max_features=0.9, max_samples=0.9, min_samples_split=16, n_estimators=4000; total time=  59.3s
# [CV] END max_depth=2, max_features=0.7, max_samples=0.7, min_samples_split=8, n_estimators=3800; total time=  50.1s
# [CV] END max_depth=2, max_features=0.7, max_samples=0.7, min_samples_split=8, n_estimators=3800; total time=  50.0s
# [CV] END max_depth=2, max_features=0.7, max_samples=0.7, min_samples_split=8, n_estimators=3800; total time=  49.8s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.4, min_samples_split=2, n_estimators=2900; total time=  28.3s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.4, min_samples_split=2, n_estimators=2900; total time=  28.6s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.4, min_samples_split=2, n_estimators=2900; total time=  29.0s
# [CV] END max_depth=4, max_features=0.7, max_samples=0.7, min_samples_split=2, n_estimators=2600; total time=  32.7s
# [CV] END max_depth=4, max_features=0.7, max_samples=0.7, min_samples_split=2, n_estimators=2600; total time=  32.8s
# [CV] END max_depth=4, max_features=0.7, max_samples=0.7, min_samples_split=2, n_estimators=2600; total time=  32.2s
# [CV] END max_depth=8, max_features=0.6, max_samples=0.4, min_samples_split=32, n_estimators=4200; total time=  44.3s
# [CV] END max_depth=8, max_features=0.6, max_samples=0.4, min_samples_split=32, n_estimators=4200; total time=  44.2s
# [CV] END max_depth=8, max_features=0.6, max_samples=0.4, min_samples_split=32, n_estimators=4200; total time=  43.5s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.7, min_samples_split=32, n_estimators=4000; total time=  50.4s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.7, min_samples_split=32, n_estimators=4000; total time=  50.5s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.7, min_samples_split=32, n_estimators=4000; total time=  50.2s
# [CV] END max_depth=16, max_features=1.0, max_samples=0.7, min_samples_split=4, n_estimators=3500; total time= 1.6min
# [CV] END max_depth=16, max_features=1.0, max_samples=0.7, min_samples_split=4, n_estimators=3500; total time= 1.6min
# [CV] END max_depth=16, max_features=1.0, max_samples=0.7, min_samples_split=4, n_estimators=3500; total time= 1.6min
# [CV] END max_depth=16, max_features=0.9, max_samples=0.7, min_samples_split=16, n_estimators=3600; total time= 1.5min
# [CV] END max_depth=16, max_features=0.9, max_samples=0.7, min_samples_split=16, n_estimators=3600; total time= 1.5min
# [CV] END max_depth=16, max_features=0.9, max_samples=0.7, min_samples_split=16, n_estimators=3600; total time= 1.5min
# [CV] END max_depth=8, max_features=0.4, max_samples=0.7, min_samples_split=8, n_estimators=3700; total time=  46.7s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.7, min_samples_split=8, n_estimators=3700; total time=  46.7s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.7, min_samples_split=8, n_estimators=3700; total time=  46.8s
# [CV] END max_depth=2, max_features=0.8, max_samples=0.7, min_samples_split=4, n_estimators=4200; total time=  55.9s
# [CV] END max_depth=2, max_features=0.8, max_samples=0.7, min_samples_split=4, n_estimators=4200; total time=  55.6s
# [CV] END max_depth=2, max_features=0.8, max_samples=0.7, min_samples_split=4, n_estimators=4200; total time=  55.3s
# [CV] END max_depth=8, max_features=0.4, max_samples=1.0, min_samples_split=16, n_estimators=3200; total time=  49.1s
# [CV] END max_depth=8, max_features=0.4, max_samples=1.0, min_samples_split=16, n_estimators=3200; total time=  49.4s
# [CV] END max_depth=8, max_features=0.4, max_samples=1.0, min_samples_split=16, n_estimators=3200; total time=  49.3s
# [CV] END max_depth=4, max_features=0.5, max_samples=0.6, min_samples_split=2, n_estimators=3000; total time=  33.5s
# [CV] END max_depth=4, max_features=0.5, max_samples=0.6, min_samples_split=2, n_estimators=3000; total time=  33.5s
# [CV] END max_depth=4, max_features=0.5, max_samples=0.6, min_samples_split=2, n_estimators=3000; total time=  33.4s
# [CV] END max_depth=16, max_features=0.5, max_samples=0.6, min_samples_split=32, n_estimators=2200; total time=  36.9s
# [CV] END max_depth=16, max_features=0.5, max_samples=0.6, min_samples_split=32, n_estimators=2200; total time=  37.0s
# [CV] END max_depth=16, max_features=0.5, max_samples=0.6, min_samples_split=32, n_estimators=2200; total time=  37.0s
# [CV] END max_depth=16, max_features=0.9, max_samples=0.9, min_samples_split=8, n_estimators=2800; total time= 1.4min
# [CV] END max_depth=16, max_features=0.9, max_samples=0.9, min_samples_split=8, n_estimators=2800; total time= 1.4min
# [CV] END max_depth=16, max_features=0.9, max_samples=0.9, min_samples_split=8, n_estimators=2800; total time= 1.4min
# [CV] END max_depth=8, max_features=0.8, max_samples=1.0, min_samples_split=4, n_estimators=3200; total time=  59.4s
# [CV] END max_depth=8, max_features=0.8, max_samples=1.0, min_samples_split=4, n_estimators=3200; total time=  59.6s
# [CV] END max_depth=8, max_features=0.8, max_samples=1.0, min_samples_split=4, n_estimators=3200; total time=  59.7s
# [CV] END max_depth=16, max_features=0.9, max_samples=0.5, min_samples_split=8, n_estimators=3800; total time= 1.3min
# [CV] END max_depth=16, max_features=0.9, max_samples=0.5, min_samples_split=8, n_estimators=3800; total time= 1.3min
# [CV] END max_depth=16, max_features=0.9, max_samples=0.5, min_samples_split=8, n_estimators=3800; total time= 1.3min
# [CV] END max_depth=16, max_features=0.8, max_samples=0.5, min_samples_split=4, n_estimators=4200; total time= 1.4min
# [CV] END max_depth=16, max_features=0.8, max_samples=0.5, min_samples_split=4, n_estimators=4200; total time= 1.4min
# [CV] END max_depth=16, max_features=0.8, max_samples=0.5, min_samples_split=4, n_estimators=4200; total time= 1.5min
# [CV] END max_depth=8, max_features=0.6, max_samples=0.9, min_samples_split=4, n_estimators=2500; total time=  39.7s
# [CV] END max_depth=8, max_features=0.6, max_samples=0.9, min_samples_split=4, n_estimators=2500; total time=  39.9s
# [CV] END max_depth=8, max_features=0.6, max_samples=0.9, min_samples_split=4, n_estimators=2500; total time=  39.8s
# [CV] END max_depth=8, max_features=0.7, max_samples=0.6, min_samples_split=4, n_estimators=1400; total time=  18.5s
# [CV] END max_depth=8, max_features=0.7, max_samples=0.6, min_samples_split=4, n_estimators=1400; total time=  18.5s
# [CV] END max_depth=8, max_features=0.7, max_samples=0.6, min_samples_split=4, n_estimators=1400; total time=  18.4s
# [CV] END max_depth=16, max_features=0.7, max_samples=0.7, min_samples_split=2, n_estimators=3600; total time= 1.4min
# [CV] END max_depth=16, max_features=0.7, max_samples=0.7, min_samples_split=2, n_estimators=3600; total time= 1.4min
# [CV] END max_depth=16, max_features=0.7, max_samples=0.7, min_samples_split=2, n_estimators=3600; total time= 1.4min
# [CV] END max_depth=8, max_features=0.4, max_samples=0.4, min_samples_split=32, n_estimators=1600; total time=  15.7s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.4, min_samples_split=32, n_estimators=1600; total time=  15.6s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.4, min_samples_split=32, n_estimators=1600; total time=  15.8s
# [CV] END max_depth=8, max_features=0.7, max_samples=0.5, min_samples_split=8, n_estimators=2300; total time=  27.4s
# [CV] END max_depth=8, max_features=0.7, max_samples=0.5, min_samples_split=8, n_estimators=2300; total time=  27.3s
# [CV] END max_depth=8, max_features=0.7, max_samples=0.5, min_samples_split=8, n_estimators=2300; total time=  27.4s
# [CV] END max_depth=2, max_features=1.0, max_samples=0.4, min_samples_split=8, n_estimators=3100; total time=  29.7s
# [CV] END max_depth=2, max_features=1.0, max_samples=0.4, min_samples_split=8, n_estimators=3100; total time=  30.2s
# [CV] END max_depth=2, max_features=1.0, max_samples=0.4, min_samples_split=8, n_estimators=3100; total time=  30.4s
# [CV] END max_depth=8, max_features=0.7, max_samples=0.7, min_samples_split=32, n_estimators=4100; total time=  58.0s
# [CV] END max_depth=8, max_features=0.7, max_samples=0.7, min_samples_split=32, n_estimators=4100; total time=  58.5s
# [CV] END max_depth=8, max_features=0.7, max_samples=0.7, min_samples_split=32, n_estimators=4100; total time=  58.1s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.7, min_samples_split=2, n_estimators=1500; total time=  17.9s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.7, min_samples_split=2, n_estimators=1500; total time=  17.7s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.7, min_samples_split=2, n_estimators=1500; total time=  17.7s
# [CV] END max_depth=8, max_features=0.8, max_samples=0.5, min_samples_split=32, n_estimators=4300; total time=  52.7s
# [CV] END max_depth=8, max_features=0.8, max_samples=0.5, min_samples_split=32, n_estimators=4300; total time=  52.6s
# [CV] END max_depth=8, max_features=0.8, max_samples=0.5, min_samples_split=32, n_estimators=4300; total time=  53.1s
# [CV] END max_depth=8, max_features=0.5, max_samples=0.5, min_samples_split=8, n_estimators=1000; total time=  11.1s
# [CV] END max_depth=8, max_features=0.5, max_samples=0.5, min_samples_split=8, n_estimators=1000; total time=  10.9s
# [CV] END max_depth=8, max_features=0.5, max_samples=0.5, min_samples_split=8, n_estimators=1000; total time=  11.1s
# [CV] END max_depth=4, max_features=0.7, max_samples=0.8, min_samples_split=8, n_estimators=2500; total time=  33.4s
# [CV] END max_depth=4, max_features=0.7, max_samples=0.8, min_samples_split=8, n_estimators=2500; total time=  33.5s
# [CV] END max_depth=4, max_features=0.7, max_samples=0.8, min_samples_split=8, n_estimators=2500; total time=  33.5s
# [CV] END max_depth=16, max_features=0.4, max_samples=0.8, min_samples_split=16, n_estimators=3900; total time= 1.2min
# [CV] END max_depth=16, max_features=0.4, max_samples=0.8, min_samples_split=16, n_estimators=3900; total time= 1.2min
# [CV] END max_depth=16, max_features=0.4, max_samples=0.8, min_samples_split=16, n_estimators=3900; total time= 1.2min
# [CV] END max_depth=4, max_features=0.5, max_samples=1.0, min_samples_split=32, n_estimators=2100; total time=  31.1s
# [CV] END max_depth=4, max_features=0.5, max_samples=1.0, min_samples_split=32, n_estimators=2100; total time=  31.0s
# [CV] END max_depth=4, max_features=0.5, max_samples=1.0, min_samples_split=32, n_estimators=2100; total time=  31.0s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.5, min_samples_split=16, n_estimators=1000; total time=  13.2s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.5, min_samples_split=16, n_estimators=1000; total time=  13.2s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.5, min_samples_split=16, n_estimators=1000; total time=  13.2s
# [CV] END max_depth=16, max_features=0.6, max_samples=0.5, min_samples_split=2, n_estimators=3400; total time= 1.0min
# [CV] END max_depth=16, max_features=0.6, max_samples=0.5, min_samples_split=2, n_estimators=3400; total time= 1.0min
# [CV] END max_depth=16, max_features=0.6, max_samples=0.5, min_samples_split=2, n_estimators=3400; total time= 1.0min
# [CV] END max_depth=2, max_features=0.5, max_samples=1.0, min_samples_split=4, n_estimators=4800; total time= 1.3min
# [CV] END max_depth=2, max_features=0.5, max_samples=1.0, min_samples_split=4, n_estimators=4800; total time= 1.3min
# [CV] END max_depth=2, max_features=0.5, max_samples=1.0, min_samples_split=4, n_estimators=4800; total time= 1.3min
# [CV] END max_depth=16, max_features=1.0, max_samples=0.6, min_samples_split=8, n_estimators=1900; total time=  44.4s
# [CV] END max_depth=16, max_features=1.0, max_samples=0.6, min_samples_split=8, n_estimators=1900; total time=  44.9s
# [CV] END max_depth=16, max_features=1.0, max_samples=0.6, min_samples_split=8, n_estimators=1900; total time=  44.9s
# [CV] END max_depth=2, max_features=0.7, max_samples=0.4, min_samples_split=16, n_estimators=3100; total time=  29.5s
# [CV] END max_depth=2, max_features=0.7, max_samples=0.4, min_samples_split=16, n_estimators=3100; total time=  29.5s
# [CV] END max_depth=2, max_features=0.7, max_samples=0.4, min_samples_split=16, n_estimators=3100; total time=  29.3s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.6, min_samples_split=16, n_estimators=1500; total time=  17.8s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.6, min_samples_split=16, n_estimators=1500; total time=  18.0s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.6, min_samples_split=16, n_estimators=1500; total time=  17.9s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.5, min_samples_split=4, n_estimators=4200; total time=  41.6s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.5, min_samples_split=4, n_estimators=4200; total time=  42.0s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.5, min_samples_split=4, n_estimators=4200; total time=  42.2s
# ...
# [CV] END max_depth=4, max_features=1.0, max_samples=0.8, min_samples_split=2, n_estimators=2200; total time=  29.8s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.8, min_samples_split=2, n_estimators=2200; total time=  29.8s
# [CV] END max_depth=2, max_features=0.4, max_samples=1.0, min_samples_split=32, n_estimators=1400; total time=  23.9s
# [CV] END max_depth=2, max_features=0.4, max_samples=1.0, min_samples_split=32, n_estimators=1400; total time=  24.1s
# [CV] END max_depth=2, max_features=0.4, max_samples=1.0, min_samples_split=32, n_estimators=1400; total time=  24.2s
# [CV] END max_depth=16, max_features=0.9, max_samples=0.8, min_samples_split=16, n_estimators=2000; total time=  53.5s
# [CV] END max_depth=16, max_features=0.9, max_samples=0.8, min_samples_split=16, n_estimators=2000; total time=  52.8s
# [CV] END max_depth=16, max_features=0.9, max_samples=0.8, min_samples_split=16, n_estimators=2000; total time=  53.5s
# [CV] END max_depth=2, max_features=1.0, max_samples=0.4, min_samples_split=4, n_estimators=2700; total time=  26.5s
# [CV] END max_depth=2, max_features=1.0, max_samples=0.4, min_samples_split=4, n_estimators=2700; total time=  26.4s
# [CV] END max_depth=2, max_features=1.0, max_samples=0.4, min_samples_split=4, n_estimators=2700; total time=  26.1s
# [CV] END max_depth=8, max_features=0.8, max_samples=0.9, min_samples_split=2, n_estimators=2900; total time=  50.2s
# [CV] END max_depth=8, max_features=0.8, max_samples=0.9, min_samples_split=2, n_estimators=2900; total time=  50.7s
# [CV] END max_depth=8, max_features=0.8, max_samples=0.9, min_samples_split=2, n_estimators=2900; total time=  50.8s
# [CV] END max_depth=4, max_features=1.0, max_samples=0.9, min_samples_split=2, n_estimators=4300; total time= 1.1min
# [CV] END max_depth=4, max_features=1.0, max_samples=0.9, min_samples_split=2, n_estimators=4300; total time= 1.1min
# [CV] END max_depth=4, max_features=1.0, max_samples=0.9, min_samples_split=2, n_estimators=4300; total time= 1.1min
# [CV] END max_depth=8, max_features=1.0, max_samples=0.4, min_samples_split=8, n_estimators=4300; total time=  50.5s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.4, min_samples_split=8, n_estimators=4300; total time=  50.4s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.4, min_samples_split=8, n_estimators=4300; total time=  50.3s
# [CV] END max_depth=8, max_features=0.8, max_samples=0.9, min_samples_split=4, n_estimators=2800; total time=  48.2s
# [CV] END max_depth=8, max_features=0.8, max_samples=0.9, min_samples_split=4, n_estimators=2800; total time=  48.3s
# [CV] END max_depth=8, max_features=0.8, max_samples=0.9, min_samples_split=4, n_estimators=2800; total time=  48.0s
# [CV] END max_depth=8, max_features=0.7, max_samples=0.5, min_samples_split=2, n_estimators=3600; total time=  42.0s
# [CV] END max_depth=8, max_features=0.7, max_samples=0.5, min_samples_split=2, n_estimators=3600; total time=  42.3s
# [CV] END max_depth=8, max_features=0.7, max_samples=0.5, min_samples_split=2, n_estimators=3600; total time=  42.2s
# [CV] END max_depth=16, max_features=0.6, max_samples=0.8, min_samples_split=16, n_estimators=2800; total time= 1.0min
# [CV] END max_depth=16, max_features=0.6, max_samples=0.8, min_samples_split=16, n_estimators=2800; total time= 1.0min
# [CV] END max_depth=16, max_features=0.6, max_samples=0.8, min_samples_split=16, n_estimators=2800; total time= 1.0min
# [CV] END max_depth=2, max_features=0.9, max_samples=0.5, min_samples_split=2, n_estimators=3900; total time=  41.4s
# [CV] END max_depth=2, max_features=0.9, max_samples=0.5, min_samples_split=2, n_estimators=3900; total time=  42.0s
# [CV] END max_depth=2, max_features=0.9, max_samples=0.5, min_samples_split=2, n_estimators=3900; total time=  41.2s
# [CV] END max_depth=2, max_features=0.9, max_samples=0.6, min_samples_split=8, n_estimators=4400; total time=  52.7s
# [CV] END max_depth=2, max_features=0.9, max_samples=0.6, min_samples_split=8, n_estimators=4400; total time=  52.3s
# [CV] END max_depth=2, max_features=0.9, max_samples=0.6, min_samples_split=8, n_estimators=4400; total time=  52.4s
# [CV] END max_depth=16, max_features=0.5, max_samples=0.6, min_samples_split=8, n_estimators=1000; total time=  17.4s
# [CV] END max_depth=16, max_features=0.5, max_samples=0.6, min_samples_split=8, n_estimators=1000; total time=  17.6s
# [CV] END max_depth=16, max_features=0.5, max_samples=0.6, min_samples_split=8, n_estimators=1000; total time=  17.6s
# [CV] END max_depth=16, max_features=0.9, max_samples=0.7, min_samples_split=32, n_estimators=2000; total time=  46.4s
# [CV] END max_depth=16, max_features=0.9, max_samples=0.7, min_samples_split=32, n_estimators=2000; total time=  46.5s
# [CV] END max_depth=16, max_features=0.9, max_samples=0.7, min_samples_split=32, n_estimators=2000; total time=  46.6s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.4, min_samples_split=32, n_estimators=3300; total time=  31.8s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.4, min_samples_split=32, n_estimators=3300; total time=  31.8s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.4, min_samples_split=32, n_estimators=3300; total time=  31.8s
# [CV] END max_depth=4, max_features=0.9, max_samples=1.0, min_samples_split=16, n_estimators=1400; total time=  21.4s
# [CV] END max_depth=4, max_features=0.9, max_samples=1.0, min_samples_split=16, n_estimators=1400; total time=  21.5s
# [CV] END max_depth=4, max_features=0.9, max_samples=1.0, min_samples_split=16, n_estimators=1400; total time=  21.4s
# [CV] END max_depth=16, max_features=1.0, max_samples=0.7, min_samples_split=32, n_estimators=2000; total time=  48.6s
# [CV] END max_depth=16, max_features=1.0, max_samples=0.7, min_samples_split=32, n_estimators=2000; total time=  48.8s
# [CV] END max_depth=16, max_features=1.0, max_samples=0.7, min_samples_split=32, n_estimators=2000; total time=  49.0s
# [CV] END max_depth=2, max_features=0.4, max_samples=0.5, min_samples_split=2, n_estimators=1500; total time=  16.1s
# [CV] END max_depth=2, max_features=0.4, max_samples=0.5, min_samples_split=2, n_estimators=1500; total time=  16.1s
# [CV] END max_depth=2, max_features=0.4, max_samples=0.5, min_samples_split=2, n_estimators=1500; total time=  16.0s
# [CV] END max_depth=8, max_features=0.5, max_samples=0.6, min_samples_split=32, n_estimators=4500; total time=  53.4s
# [CV] END max_depth=8, max_features=0.5, max_samples=0.6, min_samples_split=32, n_estimators=4500; total time=  54.1s
# [CV] END max_depth=8, max_features=0.5, max_samples=0.6, min_samples_split=32, n_estimators=4500; total time=  53.9s
# [CV] END max_depth=16, max_features=0.4, max_samples=0.9, min_samples_split=16, n_estimators=5000; total time= 1.7min
# [CV] END max_depth=16, max_features=0.4, max_samples=0.9, min_samples_split=16, n_estimators=5000; total time= 1.7min
# [CV] END max_depth=16, max_features=0.4, max_samples=0.9, min_samples_split=16, n_estimators=5000; total time= 1.8min
# [CV] END max_depth=2, max_features=0.9, max_samples=0.5, min_samples_split=4, n_estimators=3700; total time=  40.4s
# [CV] END max_depth=2, max_features=0.9, max_samples=0.5, min_samples_split=4, n_estimators=3700; total time=  39.8s
# [CV] END max_depth=2, max_features=0.9, max_samples=0.5, min_samples_split=4, n_estimators=3700; total time=  39.2s
# [CV] END max_depth=8, max_features=0.9, max_samples=1.0, min_samples_split=8, n_estimators=3300; total time= 1.1min
# [CV] END max_depth=8, max_features=0.9, max_samples=1.0, min_samples_split=8, n_estimators=3300; total time= 1.1min
# [CV] END max_depth=8, max_features=0.9, max_samples=1.0, min_samples_split=8, n_estimators=3300; total time= 1.1min
# [CV] END max_depth=16, max_features=0.7, max_samples=0.8, min_samples_split=8, n_estimators=3100; total time= 1.2min
# [CV] END max_depth=16, max_features=0.7, max_samples=0.8, min_samples_split=8, n_estimators=3100; total time= 1.3min
# [CV] END max_depth=16, max_features=0.7, max_samples=0.8, min_samples_split=8, n_estimators=3100; total time= 1.2min
# [CV] END max_depth=4, max_features=0.8, max_samples=0.9, min_samples_split=4, n_estimators=4500; total time= 1.1min
# [CV] END max_depth=4, max_features=0.8, max_samples=0.9, min_samples_split=4, n_estimators=4500; total time= 1.1min
# [CV] END max_depth=4, max_features=0.8, max_samples=0.9, min_samples_split=4, n_estimators=4500; total time= 1.1min
# [CV] END max_depth=2, max_features=0.5, max_samples=0.4, min_samples_split=4, n_estimators=1800; total time=  17.0s
# [CV] END max_depth=2, max_features=0.5, max_samples=0.4, min_samples_split=4, n_estimators=1800; total time=  17.1s
# [CV] END max_depth=2, max_features=0.5, max_samples=0.4, min_samples_split=4, n_estimators=1800; total time=  17.0s
# [CV] END max_depth=2, max_features=0.8, max_samples=0.7, min_samples_split=16, n_estimators=1200; total time=  15.7s
# [CV] END max_depth=2, max_features=0.8, max_samples=0.7, min_samples_split=16, n_estimators=1200; total time=  15.8s
# [CV] END max_depth=2, max_features=0.8, max_samples=0.7, min_samples_split=16, n_estimators=1200; total time=  15.8s
# [CV] END max_depth=8, max_features=0.5, max_samples=0.4, min_samples_split=32, n_estimators=4900; total time=  48.1s
# [CV] END max_depth=8, max_features=0.5, max_samples=0.4, min_samples_split=32, n_estimators=4900; total time=  48.8s
# [CV] END max_depth=8, max_features=0.5, max_samples=0.4, min_samples_split=32, n_estimators=4900; total time=  48.7s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.5, min_samples_split=8, n_estimators=4700; total time=  49.8s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.5, min_samples_split=8, n_estimators=4700; total time=  50.2s
# [CV] END max_depth=8, max_features=0.4, max_samples=0.5, min_samples_split=8, n_estimators=4700; total time=  49.8s
# [CV] END max_depth=16, max_features=0.5, max_samples=0.4, min_samples_split=8, n_estimators=2600; total time=  37.6s
# [CV] END max_depth=16, max_features=0.5, max_samples=0.4, min_samples_split=8, n_estimators=2600; total time=  37.8s
# [CV] END max_depth=16, max_features=0.5, max_samples=0.4, min_samples_split=8, n_estimators=2600; total time=  37.8s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.7, min_samples_split=32, n_estimators=2100; total time=  24.2s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.7, min_samples_split=32, n_estimators=2100; total time=  24.3s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.7, min_samples_split=32, n_estimators=2100; total time=  24.0s
# [CV] END max_depth=2, max_features=0.9, max_samples=0.6, min_samples_split=16, n_estimators=2300; total time=  27.4s
# [CV] END max_depth=2, max_features=0.9, max_samples=0.6, min_samples_split=16, n_estimators=2300; total time=  28.0s
# [CV] END max_depth=2, max_features=0.9, max_samples=0.6, min_samples_split=16, n_estimators=2300; total time=  27.3s
# [CV] END max_depth=8, max_features=0.9, max_samples=0.7, min_samples_split=8, n_estimators=2100; total time=  31.7s
# [CV] END max_depth=8, max_features=0.9, max_samples=0.7, min_samples_split=8, n_estimators=2100; total time=  32.4s
# [CV] END max_depth=8, max_features=0.9, max_samples=0.7, min_samples_split=8, n_estimators=2100; total time=  32.5s
# [CV] END max_depth=8, max_features=0.5, max_samples=1.0, min_samples_split=32, n_estimators=3200; total time=  51.9s
# [CV] END max_depth=8, max_features=0.5, max_samples=1.0, min_samples_split=32, n_estimators=3200; total time=  51.2s
# [CV] END max_depth=8, max_features=0.5, max_samples=1.0, min_samples_split=32, n_estimators=3200; total time=  51.7s
# [CV] END max_depth=8, max_features=0.9, max_samples=0.8, min_samples_split=8, n_estimators=2400; total time=  40.6s
# [CV] END max_depth=8, max_features=0.9, max_samples=0.8, min_samples_split=8, n_estimators=2400; total time=  40.1s
# [CV] END max_depth=8, max_features=0.9, max_samples=0.8, min_samples_split=8, n_estimators=2400; total time=  39.8s
# [CV] END max_depth=2, max_features=0.8, max_samples=0.5, min_samples_split=8, n_estimators=1900; total time=  20.3s
# [CV] END max_depth=2, max_features=0.8, max_samples=0.5, min_samples_split=8, n_estimators=1900; total time=  20.6s
# [CV] END max_depth=2, max_features=0.8, max_samples=0.5, min_samples_split=8, n_estimators=1900; total time=  20.1s
# [CV] END max_depth=4, max_features=0.7, max_samples=0.6, min_samples_split=32, n_estimators=2900; total time=  31.7s
# [CV] END max_depth=4, max_features=0.7, max_samples=0.6, min_samples_split=32, n_estimators=2900; total time=  32.3s
# [CV] END max_depth=4, max_features=0.7, max_samples=0.6, min_samples_split=32, n_estimators=2900; total time=  32.2s
# [CV] END max_depth=16, max_features=0.8, max_samples=0.5, min_samples_split=2, n_estimators=5000; total time= 1.7min
# [CV] END max_depth=16, max_features=0.8, max_samples=0.5, min_samples_split=2, n_estimators=5000; total time= 1.7min
# [CV] END max_depth=16, max_features=0.8, max_samples=0.5, min_samples_split=2, n_estimators=5000; total time= 1.7min
# [CV] END max_depth=4, max_features=0.9, max_samples=0.5, min_samples_split=2, n_estimators=3700; total time=  38.9s
# [CV] END max_depth=4, max_features=0.9, max_samples=0.5, min_samples_split=2, n_estimators=3700; total time=  38.9s
# [CV] END max_depth=4, max_features=0.9, max_samples=0.5, min_samples_split=2, n_estimators=3700; total time=  38.6s
# [CV] END max_depth=2, max_features=1.0, max_samples=0.6, min_samples_split=2, n_estimators=4700; total time=  56.5s
# [CV] END max_depth=2, max_features=1.0, max_samples=0.6, min_samples_split=2, n_estimators=4700; total time=  57.1s
# [CV] END max_depth=2, max_features=1.0, max_samples=0.6, min_samples_split=2, n_estimators=4700; total time=  56.4s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.4, min_samples_split=2, n_estimators=4600; total time=  40.4s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.4, min_samples_split=2, n_estimators=4600; total time=  41.7s
# [CV] END max_depth=4, max_features=0.4, max_samples=0.4, min_samples_split=2, n_estimators=4600; total time=  41.6s
# [CV] END max_depth=2, max_features=0.7, max_samples=0.9, min_samples_split=32, n_estimators=4900; total time= 1.3min
# [CV] END max_depth=2, max_features=0.7, max_samples=0.9, min_samples_split=32, n_estimators=4900; total time= 1.3min
# [CV] END max_depth=2, max_features=0.7, max_samples=0.9, min_samples_split=32, n_estimators=4900; total time= 1.3min
# [CV] END max_depth=16, max_features=0.9, max_samples=1.0, min_samples_split=2, n_estimators=2700; total time= 1.5min
# [CV] END max_depth=16, max_features=0.9, max_samples=1.0, min_samples_split=2, n_estimators=2700; total time= 1.5min
# [CV] END max_depth=16, max_features=0.9, max_samples=1.0, min_samples_split=2, n_estimators=2700; total time= 1.5min
# RandomizedSearchCV(cv=RandomRunNFoldsKFold(n_splits=10, random_state=42, run_splits=None),
#                    estimator=RandomForestRegressor(), n_iter=500,
#                    param_distributions={'max_depth': [2, 4, 8, 16],
#                                         'max_features': [0.4, 0.5, 0.6, 0.7,
#                                                          0.8, 0.9, 1.0],
#                                         'max_samples': [0.4, 0.5, 0.6, 0.7, 0.8,
#                                                         0.9, 1.0],
#                                         'min_samples_split': [2, 4, 8, 16, 32],
#                                         'n_estimators': [1000, 1100, 1200, 1300,
#                                                          1400, 1500, 1600, 1700,
#                                                          1800, 1900, 2000, 2100,
#                                                          2200, 2300, 2400, 2500,
#                                                          2600, 2700, 2800, 2900,
#                                                          3000, 3100, 3200, 3300,
#                                                          3400, 3500, 3600, 3700,
#                                                          3800, 3900, ...]},
#                    random_state=42, scoring='r2', verbose=2)

# %%
CV_result = random_search.cv_results_

# %%
pd.DataFrame(CV_result).sort_values(by='rank_test_score', ascending=True).loc[:,:].head()
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 261      17.740023      0.091343         0.751616        0.017319
# 161      67.328209      0.170901         2.549933        0.061923
# 50       56.401347      0.135879         2.525426        0.246218
# 387      69.821267      0.271292         2.954576        0.263909
# 193      20.603827      0.318864         0.760166        0.034357
#
#      param_n_estimators  param_min_samples_split  param_max_samples  \
# 261                1300                        4                0.4
# 161                3900                        8                0.7
# 50                 3900                        8                0.5
# 387                4400                        8                0.6
# 193                1300                        8                0.6
#
#      param_max_features  param_max_depth  \
# 261                 0.4               16
# 161                 0.4               16
# 50                  0.4               16
# 387                 0.4               16
# 193                 0.4               16
#
#                                                 params  split0_test_score  \
# 261  {'n_estimators': 1300, 'min_samples_split': 4,...           0.384120
# 161  {'n_estimators': 3900, 'min_samples_split': 8,...           0.383849
# 50   {'n_estimators': 3900, 'min_samples_split': 8,...           0.383926
# 387  {'n_estimators': 4400, 'min_samples_split': 8,...           0.383901
# 193  {'n_estimators': 1300, 'min_samples_split': 8,...           0.383941
#
#      split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 261           0.378337           0.379244         0.380567        0.002539
# 161           0.378421           0.379295         0.380521        0.002380
# 50            0.378315           0.379255         0.380498        0.002454
# 387           0.378257           0.379219         0.380459        0.002465
# 193           0.378192           0.379205         0.380446        0.002506
#
#      rank_test_score
# 261                1
# 161                2
# 50                 3
# 387                4
# 193                5

# %%
dump(random_search, '03_Results/RandomSearch500_5hyper_v2.joblib')
# Out:
# ['03_Results/RandomSearch500_5hyper_v2.joblib']

# %%
pd.DataFrame(CV_result).sort_values(by='rank_test_score', ascending=True).to_csv('03_Results/RandomSearch500_hyper_v2.csv')

# %% [markdown]
# ### Test Perfromance

# %%
random_search.best_params_
# Out:
# {'n_estimators': 1300,
#  'min_samples_split': 4,
#  'max_samples': 0.4,
#  'max_features': 0.4,
#  'max_depth': 16}

# %%
rf_reg_final =RandomForestRegressor(**random_search.best_params_)
rf_reg_final.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
# Predictions
y_pred = rf_reg_final.predict(X_test)

# %%
y_pred
# Out:
# 402158    3.717990
# 110495    2.785189
# 470583    3.737490
# 176356    3.944020
# 411706    3.241077
#             ...
# 436304    3.903354
# 312634    4.057661
# 212674    4.177610
# 413227    3.302152
# 348847    3.918535
# Length: 38318, dtype: float64

# %%
r2_score(y_test, y_pred)
# Out:
# 0.37640637959522694
